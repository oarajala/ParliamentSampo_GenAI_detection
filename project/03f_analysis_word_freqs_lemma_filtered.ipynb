# %%
# import packages, declare constants, get the parent directory
import pandas as pd
import numpy as np
import re
import os
import time
#import decimal
from scipy import stats
#from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib import colormaps
#from .utils import helpers
#import simplemma
import pyvoikko

CHATGPT_RELEASE_YEAR = int(2022)
FINNISH_ALPHABET = 'abcdefghijklmnopqrstuvwxyzåäö'

def get_parent_directory() -> str:
    """Get the parent directory for handling csv files.

    Returns:
        string: the path to the directory where directories for csv files are located
    """
    #create relative path for parent
    relative_parent = os.path.join(os.getcwd(), '..')

    #use abspath for absolute parent path
    return str(os.path.abspath(relative_parent)).replace('\\', '/')

directory = get_parent_directory()

# %% [markdown]
# DECLARE FUNCTIONS

# %%
def clean_string(string: str) -> str:
    try:
        # remove blanks in start and end
        string = string.strip()
        string = string.lower()
        # the string must contain characters
        if any(c in string for c in FINNISH_ALPHABET)==False:
            string = ''
        # remove tabulations, line breaks etc., also special characters
        remove_these = r'[\+\*!"”’?.:,…()§\'[\] \t\n\r\f\v]'
        string = re.sub(remove_these, '', string)
        # remove weird parentheses and backwards linebreaks from starts of strings
        string = re.sub(r'^\)\\[a-z]', '', string)
        # remove weird '\[alphabet]' strings at start of strings
        string = re.sub(r'^\\[a-z]', '', string)
        # remove numbers
        string = re.sub(r'[0-9]', '', string)
        # remove dashes '-' at the start and end of string
        string = re.sub(r'^-|-$', '', string)
        # remove individual forward and backward slashes '/', '\'
        string = re.sub(r'[\/\\]', '', string)
        # remove double dashes '--'
        string = string.replace('--', '-')
        # remove the equal sign '='
        string = string.replace('=', '')
        # at the end of the cleaning, remove all characters from the string which are not in the alphabet except for dash (compound words)
        remove_these = ''.join([str(c) for c in string if c != '-' and c not in [i for i in FINNISH_ALPHABET]])
        string = re.sub(remove_these, '', string)
        # remove blanks in start and end again
        string = string.strip()
        # remove empty if string length < 2
        string = '' if len(string) < 2 else string
        return string
    except:
        print(f'Unexpected error at helpers.clean_string(), string: {string}')
        raise

# %%
def count_word_freqs_in_string(string: str):
    """Counts the words in the input string.
    Returns a dictionary where the word is the key and the frequency is the value.
    """
    if ((string is None) or (string == 'nan')):
        return None
    else:
        words_list = re.split(' ', string)
        wordfreq_dict = {}
        for word in words_list:
            if word not in wordfreq_dict.keys():
                wordfreq_dict[word] = 1
            else:
                wordfreq_dict[word] += 1

        return wordfreq_dict

# %%
def get_normalised(df: pd.DataFrame, speaker_id: str, year: int, word_n: int) -> float:
    w_min = df['word_n'].loc[(df['speaker_id']==speaker_id)&(df['year']==year)].min()
    w_max = df['word_n'].loc[(df['speaker_id']==speaker_id)&(df['year']==year)].max()
    return ((word_n-w_min)/(w_max-w_min))

# %%
def linear_extrapolation(y: list, x: list, n=1) -> list:
    """Linear extrapolation based on last two x and y observations. Returns the extrapolated value of y for a given x based on y1x1 and y2x2.
    Parameter x will be standardised to a running sequence of numbers so extrapolations works on a linear scale.
    Args:
        y (list): list of values
        x (list): list of values
        n (int, optional): for how many times shall extrapolation be done. Defaults to 1. Larger values will start extrapolating on extrapolated values.

    Returns:
        list: extrapolated value(s) of y. The length of the list will be n.
    """
    # x and y must be arrays of same length
    # CHANGE THIS TO ASSERT
    if len(y) != len(x):
        print('array length mismatch')
        return None
    else:
        # format helper parameters to not modify lists outside the function
        xx = [*[i for i in x]]
        yy = [*[i for i in y]]
        return_list = [] # format list to be returned
        # loop n times -> return list of n length with n extrapolations
        # note: extrapolating on extrapolations if n>1
        while n >= 1:
            # format xx: it shall take a running sequence of numbers as its values
            xx = [i for i in range(len(x))]
            m = (yy[-1] - yy[-2]) / (xx[-1] - xx[-2])
            y_v = yy[-2] + m * ((xx[-1] + 1) - xx[-2])
            xx.append([xx[-1]+1])
            yy.append(y_v)
            return_list.append(y_v)
            n = n-1
        return return_list

# %%
## filtered lemmatised csvs
df_speech_lengths = pd.read_csv(f'{directory}/csv_analysis/filtered/speaker_speech_lengths_lemma.csv', sep=';', header=0, encoding='utf-8')
df_speeches_combined_length = pd.read_csv(f'{directory}/csv_analysis/filtered/speeches_combined_plus_length_lemma.csv', sep=';', header=0, encoding='utf-8', dtype=str)
df_speaker_words_year = pd.read_csv(f'{directory}/csv_analysis/filtered/speaker_words_comp.csv', sep=';', header=0, encoding='utf-8')
df_speaker_words_data = pd.read_csv(f'{directory}/csv_analysis/filtered/speaker_words_comp_wide.csv', sep=';', header=0, encoding='utf-8')

# %%
# VISUALISATION
# the minimum length of of speeches HAS increased insce the relase of chatgpt, although not by much
# plug in means and maxes, not much change there
x = df_speech_lengths['year'].unique()

fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, sharex=True)

def plot_mins():
    avg_min = []
    for year in df_speech_lengths['year'].unique():
        avg_min.append(df_speech_lengths['len_min'].loc[df_speech_lengths['year']==year].mean())

    for speaker in df_speech_lengths['speaker_id'].unique():
        y_min = df_speech_lengths['len_min'][df_speech_lengths['speaker_id']==speaker].tolist()
        ax1.plot(x, y_min, color='grey', linestyle='dashed', linewidth=1)

    ax1.plot(x, avg_min, '.-', color='red')

    ax1.title.set_text('minimum amount of words in a speech')
    ax1.set_ylabel('words')

def plot_maxs():
    avg_max = []
    for year in df_speech_lengths['year'].unique():
        avg_max.append(df_speech_lengths['len_max'].loc[df_speech_lengths['year']==year].mean())

    for speaker in df_speech_lengths['speaker_id'].unique():
        y_max = df_speech_lengths['len_max'][df_speech_lengths['speaker_id']==speaker].tolist()
        ax2.plot(x, y_max, color='grey', linestyle='dashed', linewidth=1)

    ax2.plot(x, avg_max, '.-', color='red')

    ax2.title.set_text('maximum amount of words in a speech')
    ax2.set_ylabel('words')

def plot_means():
    avg_mean = []
    for year in df_speech_lengths['year'].unique():
        avg_mean.append(df_speech_lengths['len_mean'].loc[df_speech_lengths['year']==year].mean())

    for speaker in df_speech_lengths['speaker_id'].unique():
        y_mean = df_speech_lengths['len_mean'][df_speech_lengths['speaker_id']==speaker].tolist()
        ax3.plot(x, y_mean, color='grey', linestyle='dashed', linewidth=1)

    ax3.plot(x, avg_mean, '.-', color='red')

    ax3.title.set_text('mean amount of words in a speech')
    ax3.set_ylabel('words')
    ax3.set_xlabel('year')

def plot_medians():
    avg_median = []
    for year in df_speech_lengths['year'].unique():
        avg_median.append(df_speech_lengths['len_median'].loc[df_speech_lengths['year']==year].median())

    for speaker in df_speech_lengths['speaker_id'].unique():
        y_mean = df_speech_lengths['len_median'][df_speech_lengths['speaker_id']==speaker].tolist()
        ax4.plot(x, y_mean, color='grey', linestyle='dashed', linewidth=1)

    ax4.plot(x, avg_median, '.-', color='red')

    ax4.title.set_text('median amount of words in a speech')
    ax4.set_ylabel('words')
    ax4.set_xlabel('year')

def plot_total():
    avg_total = []
    for year in df_speech_lengths['year'].unique():
        avg_total.append(df_speech_lengths['words_total'].loc[df_speech_lengths['year']==year].mean())

    for speaker in df_speech_lengths['speaker_id'].unique():
        y_total = df_speech_lengths['words_total'][df_speech_lengths['speaker_id']==speaker].tolist()
        ax5.plot(x, y_total, color='grey', linestyle='dashed', linewidth=1)

    ax5.plot(x, avg_total, '.-', color='red')

    ax5.title.set_text('total amount of words in a speech')
    ax5.set_ylabel('words')
    ax5.set_xlabel('year')    
 
for ax in fig.get_axes():
    ax.label_outer()

fig.set_figheight(10)
fig.set_figwidth(10)
fig.set_constrained_layout(constrained=True)
plot_mins()
plot_maxs()
plot_means()
plot_medians()
plot_total()

plt.xticks(df_speech_lengths['year'].unique())
plt.show()

# %%
x = df_speech_lengths['year'].unique()

def plot_total_bar():
    y_total_bar = []
    for year in df_speech_lengths['year'].unique():
        y_total_bar.append(df_speech_lengths['words_total'].loc[df_speech_lengths['year']==year].sum())

    plt.bar(x, height=y_total_bar)
    plt.title('total amount of words per year')
    plt.ylabel('words')
    plt.xlabel('year')  

plot_total_bar()
plt.xticks(df_speech_lengths['year'].unique())
plt.show()

# %%
years = [re.search(r'\d+', i)[0] for i in df_speaker_words_data.columns if re.search(r'word_n_\d+', i)]
# define set colors for each word class across multiple pie charts
colours = {}
cm = iter(colormaps['tab20c'].colors)
for c in df_speaker_words_data['word_class'].unique():
    colours[c] = next(cm)
for year in years:
    plot_this = pd.DataFrame(columns=['year','class','n']).astype({'year':int,'class':str,'n':int})
    classes = df_speaker_words_data['word_class'].loc[df_speaker_words_data[f'word_n_{year}'].notna()].unique()
    l = []
    for c in classes:
        l.append(c)
        plot_this = pd.concat([plot_this, pd.DataFrame.from_dict({'year':[year],'class':[c],'n':[df_speaker_words_data[f'word_norm_{year}'].loc[(df_speaker_words_data[f'word_norm_{year}'].notna())&(df_speaker_words_data['word_class']==c)].sum()]})])
    plt.pie(x=plot_this['n'], labels=l, autopct='%1.1f%%', colors=[colours[i] for i in [i for i in l]])
    plt.title(year)
    plt.show()

# %%
# VISUALISATION:
# the development of frequencies of word classes
## ratio of word class against all word classes annually
years = [re.search(r'\d+', i)[0] for i in df_speaker_words_data.columns if re.search(r'word_n_\d+', i)]
classes = df_speaker_words_data['word_class'].unique()

for c in classes:
    plot_this = pd.DataFrame(columns=['year','class','ratio']).astype({'year':int,'class':str,'ratio':float}) 
    for year in years:
        # calculate the ratio of the word class
        sum_class = df_speaker_words_data[f'word_n_{year}'].loc[df_speaker_words_data['word_class']==c].sum()
        sum_other = df_speaker_words_data[f'word_n_{year}'].loc[df_speaker_words_data['word_class']!=c].sum()
        ratio = (sum_class/sum_other)*100

        plot_this = pd.concat([plot_this, pd.DataFrame.from_dict({'year':[year],'class':[c],'ratio':[ratio]})])

    plt.plot(years, plot_this['ratio'], color='grey', linewidth=1)
    plt.title(c)
    plt.show()

# %% [markdown]
# *VISUALISATION* LEMMATISED
#
# The line charts below show changes in the min-max normalised frequency of *some* words. Only words that have a SUM of frequency in the years 2024 and 2025 higher than the SUM of frequency in the years 2015-2023 are included. This is done to emphasise words the use of which has experienced a clear, critical increase in the past two years in the dataset.
#
# Lemmatised: the data is based on words that have been lemmatised.

# %%
# VISUALISATION (LEMMATISED): 
# plot the words, that have an increased normalised frequency in 2024 and 2025 compared to 2015-2022 (let's try this first)
## get the words 
df_speaker_words_data = pd.read_csv(f'{directory}/csv_analysis/filtered/speaker_words_comp_wide.csv', sep=';', header=0, encoding='utf-8')
## clean the word string one more time
df_speaker_words_data['word'] = df_speaker_words_data['word'].apply(clean_string)
## create a df which to plot
plot_this = pd.DataFrame(columns=['year','word','word_n','word_norm']).astype({'year':int, 'word':str, 'word_n':int, 'word_norm':float})

## populate the df
for year in [re.search(r'\d+', i)[0] for i in df_speaker_words_data.columns if re.search(r'word_norm_\d+', i)]:
    # summarise word counts per each year in a temporary df
    word_counts = df_speaker_words_data.groupby("word")[f'word_n_{year}'].sum().reset_index()
    word_counts = word_counts.rename(columns={f'word_n_{year}': 'word_n'})
    word_counts['year'] = int(year)
    word_counts['word_norm'] = None
    # normalise using min-maxing -> save in column 'word_norm'
    min_max = word_counts.groupby("year")["word_n"].agg(["min", "max"]).reset_index()
    word_counts = word_counts.merge(min_max, on='year', suffixes=('', '_stats'))
    word_counts['word_norm'] = ((word_counts['word_n']-word_counts['min'])/(word_counts['max']-word_counts['min']))
    word_counts = word_counts.drop(columns=["min", "max"])
    # concat the temp df to the final plottable df
    plot_this = pd.concat([plot_this, word_counts], axis=0, ignore_index=True)

## extract words which have increased in normalised frequency (higher word_norm in 2024, 2025 relative to 2015-2022)
### divide plot_this into 2 dataframes: one for years 2024-2025, and one for years before that
later_df = plot_this.loc[plot_this['year'].isin([2024, 2025])]
earlier_df = plot_this.loc[~plot_this['year'].isin([2024, 2025])]
later_df = later_df.loc[later_df['word'].isin(earlier_df['word'])]
later_df = later_df.merge(earlier_df[['word', 'word_norm']], on='word', suffixes=('', '_e'))
later_df = later_df[later_df['word_norm'] > later_df['word_norm_e']]
later_df = later_df.drop(columns=['word_norm_e'])
later_df = later_df.drop_duplicates()

plot_this = plot_this.loc[plot_this['word'].isin(later_df['word'])]

# %%
# LEMMATISED: 
# plot the total amounts of top 100 (by sum of word_n in years 2015-2025)
x = plot_this['year'].unique()
top_words = plot_this.groupby("word")["word_n"].sum().nlargest(100).index
df_top = plot_this[plot_this["word"].isin(top_words)]
for word in df_top['word'].unique():
    y = df_top['word_n'][df_top['word']==word]
    plt.plot(x, y, label=word, linestyle='-', color='grey')

plt.xticks(plot_this['year'].unique())
plt.title(f'total amount of top 100 most used words per year')
plt.ylabel('word n per year')
plt.show()

# %%
# LEMMATISED:
# plot the development of normalised frequencies of all words
x = plot_this['year'].unique()
for word in plot_this['word'].unique():
    y = plot_this['word_norm'].loc[plot_this['word']==word]
    plt.plot(x, y, label=word, linestyle='-', color='grey')

plt.xticks(plot_this['year'].unique())
plt.title(f'normalised frequency of word over years 2015-2025 - n words {len(plot_this['word'].unique())}')
plt.ylabel('normalised frequency, min-max norm, range 0.0-1.0')
plt.show()

# %%
# LEMMATISED:
# plot the normalised frequencies of words that have a sum of word_norm in years 2024 & 2025 larger than a sum of word_norm in years 2015-2023

# x-axis = years
x = plot_this['year'].unique()

# y-axis: word_norm
# limit only to top N words, where the difference between (2024,2025) > (years before) is the largest
later_df = plot_this.loc[plot_this['year'].isin([2024, 2025])]
earlier_df = plot_this.loc[~plot_this['year'].isin([2024, 2025])]

# order the words in later_df, descending based on the difference between word_norm values
earlier_word_norm_sums = earlier_df.groupby('word')['word_norm'].agg('sum').reset_index()
later_word_norm_sums = later_df.groupby('word')['word_norm'].agg('sum').reset_index()
compare_word_norm_sums = later_word_norm_sums.merge(earlier_word_norm_sums, how='left', on='word', suffixes=('_post','_pre'))

# keep the words where word_norm_post > word_norm_pre -> norm has increased 
compare_word_norm_sums = compare_word_norm_sums[compare_word_norm_sums['word_norm_post']>compare_word_norm_sums['word_norm_pre']]
compare_word_norm_sums.sort_values(by='word_norm_post', ascending=False, inplace=True)

# plot
for word in plot_this['word'][plot_this['word'].isin(compare_word_norm_sums['word'])]:
    y = plot_this['word_norm'].loc[plot_this['word']==word]
    plt.plot(x, y, label=word, linestyle='-', color='grey')

# show all years in the x-axis
plt.title(f'word frequencies (min-max normalisation) - lemmatised words - n {len(plot_this['word'][plot_this['word'].isin(compare_word_norm_sums['word'])])}')
plt.ylabel('word frequency, min-max norm, range 0.0-1.0')
plt.xlabel('year') 
plt.xticks(plot_this['year'].unique())
plt.show()

# %%
# print each word and its sum of frequencies in 2024-2025 (word_norm_post) and its sum of frequencies in 2015-2023 (word_norm_pre)
# ordered by difference (word_norm_post-word_norm_pre) from largest difference to smallest, a total of 412 words
compare_word_norm_sums['diff'] = (compare_word_norm_sums['word_norm_post']-compare_word_norm_sums['word_norm_pre'])
for i, d in compare_word_norm_sums.sort_values(by='diff', ascending=False).iterrows():
    print(compare_word_norm_sums.loc[i])
# Out:
# word                  tosi
# word_norm_post    0.036383
# word_norm_pre     0.014902
# diff               0.02148
# Name: 5436, dtype: object
# word                  nämä
# word_norm_post    0.021688
# word_norm_pre     0.000268
# diff               0.02142
# Name: 3314, dtype: object
# word                    me
# word_norm_post    0.021071
# word_norm_pre     0.000096
# diff              0.020975
# Name: 2906, dtype: object
# word                    ne
# word_norm_post    0.009529
# word_norm_pre     0.000731
# diff              0.008798
# Name: 3205, dtype: object
# word                edessä
# word_norm_post    0.021012
# word_norm_pre     0.015707
# diff              0.005304
# Name: 421, dtype: object
# word                    he
# word_norm_post    0.004635
# word_norm_pre     0.000452
# diff              0.004183
# Name: 921, dtype: object
# word                  lisä
# word_norm_post    0.004822
# word_norm_pre     0.000976
# diff              0.003846
# Name: 2584, dtype: object
# word                 varma
# word_norm_post    0.012375
# word_norm_pre     0.008851
# diff              0.003524
# Name: 6106, dtype: object
# word                 jälki
# word_norm_post    0.004281
# word_norm_pre      0.00228
# diff              0.002002
# Name: 1453, dtype: object
# word                  sija
# word_norm_post    0.002397
# word_norm_pre     0.000669
# diff              0.001727
# Name: 4646, dtype: object
# word                 silta
# word_norm_post    0.003462
# word_norm_pre      0.00181
# diff              0.001651
# Name: 4666, dtype: object
# word                   jää
# word_norm_post    0.002012
# word_norm_pre     0.000491
# diff              0.001522
# Name: 1494, dtype: object
# word                 oleva
# word_norm_post     0.00144
# word_norm_pre     0.000021
# diff              0.001419
# Name: 3409, dtype: object
# word                  joki
# word_norm_post    0.001362
# word_norm_pre     0.000361
# diff                 0.001
# Name: 1375, dtype: object
# word                  usko
# word_norm_post    0.003565
# word_norm_pre     0.002699
# diff              0.000866
# Name: 5851, dtype: object
# word                 toivo
# word_norm_post    0.008459
# word_norm_pre     0.007597
# diff              0.000862
# Name: 5419, dtype: object
# word                    te
# word_norm_post    0.000932
# word_norm_pre     0.000162
# diff               0.00077
# Name: 5196, dtype: object
# word              toisaalla
# word_norm_post     0.001368
# word_norm_pre      0.000626
# diff               0.000742
# Name: 5403, dtype: object
# word                   vuo
# word_norm_post    0.000784
# word_norm_pre      0.00008
# diff              0.000704
# Name: 6392, dtype: object
# word                   tee
# word_norm_post    0.000805
# word_norm_pre      0.00011
# diff              0.000694
# Name: 5198, dtype: object
# word                esillä
# word_norm_post    0.009977
# word_norm_pre     0.009336
# diff              0.000641
# Name: 673, dtype: object
# word              eutanasia
# word_norm_post      0.00114
# word_norm_pre      0.000523
# diff               0.000616
# Name: 741, dtype: object
# word                vaalia
# word_norm_post    0.000799
# word_norm_pre     0.000343
# diff              0.000456
# Name: 5885, dtype: object
# word                pidetä
# word_norm_post    0.001153
# word_norm_pre     0.000703
# diff              0.000451
# Name: 3818, dtype: object
# word                  tuli
# word_norm_post    0.000629
# word_norm_pre     0.000193
# diff              0.000436
# Name: 5484, dtype: object
# word              perusoikeusrajoitus
# word_norm_post               0.000674
# word_norm_pre                0.000256
# diff                         0.000418
# Name: 3756, dtype: object
# word                ylipää
# word_norm_post    0.000424
# word_norm_pre     0.000023
# diff              0.000401
# Name: 6631, dtype: object
# word                nuora
# word_norm_post    0.00036
# word_norm_pre     0.00003
# diff              0.00033
# Name: 3273, dtype: object
# word                 omata
# word_norm_post    0.001274
# word_norm_pre     0.000951
# diff              0.000323
# Name: 3423, dtype: object
# word              kannanhoidollinen
# word_norm_post             0.000951
# word_norm_pre              0.000636
# diff                       0.000315
# Name: 1552, dtype: object
# word              laskennallinen
# word_norm_post          0.000672
# word_norm_pre           0.000377
# diff                    0.000296
# Name: 2479, dtype: object
# word              työsuojelu
# word_norm_post      0.000424
# word_norm_pre       0.000135
# diff                0.000289
# Name: 5713, dtype: object
# word                  ilma
# word_norm_post    0.002379
# word_norm_pre     0.002106
# diff              0.000273
# Name: 1224, dtype: object
# word                  sisä
# word_norm_post    0.000318
# word_norm_pre     0.000046
# diff              0.000272
# Name: 4682, dtype: object
# word                älytön
# word_norm_post    0.000894
# word_norm_pre     0.000629
# diff              0.000265
# Name: 6693, dtype: object
# word               itäinen
# word_norm_post    0.000955
# word_norm_pre     0.000696
# diff              0.000259
# Name: 1329, dtype: object
# word              rangaistava
# word_norm_post        0.00079
# word_norm_pre        0.000567
# diff                 0.000224
# Name: 4275, dtype: object
# word              lukematon
# word_norm_post     0.000573
# word_norm_pre      0.000362
# diff               0.000211
# Name: 2648, dtype: object
# word              vastaanottoraha
# word_norm_post           0.000179
# word_norm_pre             0.00001
# diff                     0.000168
# Name: 6141, dtype: object
# word              vaalirahoitus
# word_norm_post         0.000816
# word_norm_pre           0.00065
# diff                   0.000166
# Name: 5892, dtype: object
# word                  noki
# word_norm_post    0.000191
# word_norm_pre     0.000031
# diff              0.000159
# Name: 3244, dtype: object
# word                typerä
# word_norm_post    0.000267
# word_norm_pre     0.000117
# diff               0.00015
# Name: 5620, dtype: object
# word              turvajärjestely
# word_norm_post           0.000148
# word_norm_pre                 0.0
# diff                     0.000148
# Name: 5570, dtype: object
# word                  omia
# word_norm_post    0.000148
# word_norm_pre      0.00001
# diff              0.000138
# Name: 3429, dtype: object
# word              lausuntopalaute
# word_norm_post           0.000236
# word_norm_pre            0.000103
# diff                     0.000133
# Name: 2493, dtype: object
# word              lakkoilla
# word_norm_post     0.000179
# word_norm_pre      0.000051
# diff               0.000129
# Name: 2453, dtype: object
# word               rajattu
# word_norm_post    0.000206
# word_norm_pre     0.000078
# diff              0.000127
# Name: 4238, dtype: object
# word                taikoa
# word_norm_post    0.000127
# word_norm_pre          0.0
# diff              0.000127
# Name: 5048, dtype: object
# word                henkiä
# word_norm_post    0.000127
# word_norm_pre      0.00001
# diff              0.000117
# Name: 971, dtype: object
# word              rangaistavuus
# word_norm_post          0.00036
# word_norm_pre          0.000246
# diff                   0.000115
# Name: 4276, dtype: object
# word              tarkkailuluokka
# word_norm_post           0.000124
# word_norm_pre             0.00001
# diff                     0.000114
# Name: 5139, dtype: object
# word              liikuntapalvelu
# word_norm_post           0.000134
# word_norm_pre            0.000026
# diff                     0.000108
# Name: 2563, dtype: object
# word              miljonääri
# word_norm_post      0.000254
# word_norm_pre       0.000148
# diff                0.000106
# Name: 3007, dtype: object
# word              kustannusnousu
# word_norm_post          0.000158
# word_norm_pre           0.000052
# diff                    0.000106
# Name: 2256, dtype: object
# word              veto-oikeus
# word_norm_post       0.000145
# word_norm_pre        0.000042
# diff                 0.000104
# Name: 6262, dtype: object
# word              suurpeto
# word_norm_post    0.000482
# word_norm_pre     0.000381
# diff              0.000101
# Name: 4915, dtype: object
# word              kauppalehti
# word_norm_post       0.000122
# word_norm_pre        0.000027
# diff                 0.000094
# Name: 1696, dtype: object
# word              kumppanuus
# word_norm_post      0.000328
# word_norm_pre       0.000234
# diff                0.000094
# Name: 2206, dtype: object
# word                 hullu
# word_norm_post    0.000313
# word_norm_pre     0.000219
# diff              0.000094
# Name: 1061, dtype: object
# word                ottawa
# word_norm_post    0.000242
# word_norm_pre     0.000148
# diff              0.000094
# Name: 3538, dtype: object
# word              rikosuhrimaksu
# word_norm_post          0.000148
# word_norm_pre           0.000059
# diff                    0.000089
# Name: 4396, dtype: object
# word              mineraali
# word_norm_post     0.000106
# word_norm_pre      0.000019
# diff               0.000088
# Name: 3013, dtype: object
# word                kamala
# word_norm_post    0.000594
# word_norm_pre     0.000507
# diff              0.000088
# Name: 1545, dtype: object
# word              sodankäynti
# word_norm_post       0.000106
# word_norm_pre         0.00002
# diff                 0.000086
# Name: 4738, dtype: object
# word              kulttuurinen
# word_norm_post        0.000348
# word_norm_pre         0.000262
# diff                  0.000086
# Name: 2184, dtype: object
# word                 migri
# word_norm_post    0.000106
# word_norm_pre     0.000021
# diff              0.000085
# Name: 2990, dtype: object
# word                  hymy
# word_norm_post    0.000122
# word_norm_pre     0.000037
# diff              0.000085
# Name: 1109, dtype: object
# word              häirintä
# word_norm_post     0.00027
# word_norm_pre     0.000189
# diff              0.000081
# Name: 1144, dtype: object
# word              hallittu
# word_norm_post    0.000148
# word_norm_pre     0.000068
# diff              0.000081
# Name: 851, dtype: object
# word              erillään
# word_norm_post    0.000169
# word_norm_pre     0.000093
# diff              0.000077
# Name: 648, dtype: object
# word              ruuantuotanto
# word_norm_post         0.000115
# word_norm_pre           0.00004
# diff                   0.000075
# Name: 4449, dtype: object
# word              kasvinsuojeluaine
# word_norm_post             0.000122
# word_norm_pre              0.000047
# diff                       0.000075
# Name: 1640, dtype: object
# word              aurinkovoima
# word_norm_post        0.000112
# word_norm_pre         0.000038
# diff                  0.000074
# Name: 305, dtype: object
# word              lähtökohtainen
# word_norm_post          0.000085
# word_norm_pre            0.00001
# diff                    0.000074
# Name: 2750, dtype: object
# word              neuvotteluratkaisu
# word_norm_post              0.000122
# word_norm_pre               0.000048
# diff                        0.000073
# Name: 3223, dtype: object
# word              luovutus
# word_norm_post    0.000073
# word_norm_pre          0.0
# diff              0.000073
# Name: 2693, dtype: object
# word              suojelus
# word_norm_post    0.000134
# word_norm_pre     0.000068
# diff              0.000066
# Name: 4864, dtype: object
# word                  onni
# word_norm_post    0.001032
# word_norm_pre     0.000967
# diff              0.000065
# Name: 3444, dtype: object
# word              pääkäsittely
# word_norm_post        0.000088
# word_norm_pre         0.000024
# diff                  0.000064
# Name: 4141, dtype: object
# word               paasata
# word_norm_post    0.000064
# word_norm_pre          0.0
# diff              0.000064
# Name: 3547, dtype: object
# word              sopimusehto
# word_norm_post       0.000064
# word_norm_pre             0.0
# diff                 0.000064
# Name: 4763, dtype: object
# word                 purra
# word_norm_post    0.001918
# word_norm_pre     0.001855
# diff              0.000063
# Name: 4060, dtype: object
# word              öljysuojarahasto
# word_norm_post            0.000094
# word_norm_pre             0.000031
# diff                      0.000062
# Name: 6718, dtype: object
# word              rajavartija
# word_norm_post       0.000445
# word_norm_pre        0.000383
# diff                 0.000062
# Name: 4242, dtype: object
# word              toimipaikka
# word_norm_post       0.000121
# word_norm_pre        0.000059
# diff                 0.000062
# Name: 5391, dtype: object
# word               vimpeli
# word_norm_post    0.000061
# word_norm_pre          0.0
# diff              0.000061
# Name: 6343, dtype: object
# word              sairaalaverkosto
# word_norm_post            0.000061
# word_norm_pre                  0.0
# diff                      0.000061
# Name: 4493, dtype: object
# word              aluekehitysraha
# word_norm_post           0.000185
# word_norm_pre            0.000124
# diff                      0.00006
# Name: 152, dtype: object
# word                  maku
# word_norm_post    0.000228
# word_norm_pre     0.000169
# diff              0.000059
# Name: 2868, dtype: object
# word                 keveä
# word_norm_post    0.000163
# word_norm_pre     0.000105
# diff              0.000059
# Name: 1820, dtype: object
# word              lahjaverotus
# word_norm_post        0.000064
# word_norm_pre         0.000005
# diff                  0.000059
# Name: 2398, dtype: object
# word              etelä-savo
# word_norm_post        0.0004
# word_norm_pre       0.000342
# diff                0.000058
# Name: 700, dtype: object
# word               moskova
# word_norm_post    0.000158
# word_norm_pre     0.000102
# diff              0.000056
# Name: 3076, dtype: object
# word              tekomuoto
# word_norm_post     0.000185
# word_norm_pre      0.000131
# diff               0.000054
# Name: 5224, dtype: object
# word                horjua
# word_norm_post    0.000085
# word_norm_pre     0.000031
# diff              0.000053
# Name: 1040, dtype: object
# word               kerrata
# word_norm_post     0.00086
# word_norm_pre     0.000807
# diff              0.000053
# Name: 1751, dtype: object
# word              porilainen
# word_norm_post      0.000076
# word_norm_pre       0.000023
# diff                0.000052
# Name: 3948, dtype: object
# word               riistää
# word_norm_post    0.000073
# word_norm_pre     0.000021
# diff              0.000052
# Name: 4374, dtype: object
# word              etulyöntiasema
# word_norm_post          0.000052
# word_norm_pre                0.0
# diff                    0.000052
# Name: 714, dtype: object
# word              oikeustoimi
# word_norm_post         0.0001
# word_norm_pre        0.000048
# diff                 0.000052
# Name: 3381, dtype: object
# word              sitoutunut
# word_norm_post      0.000121
# word_norm_pre       0.000071
# diff                 0.00005
# Name: 4710, dtype: object
# word              raja-arvo
# word_norm_post     0.000076
# word_norm_pre      0.000027
# diff               0.000049
# Name: 4231, dtype: object
# word                 video
# word_norm_post    0.000103
# word_norm_pre     0.000057
# diff              0.000046
# Name: 6270, dtype: object
# word              huojentaminen
# word_norm_post         0.000046
# word_norm_pre               0.0
# diff                   0.000046
# Name: 1065, dtype: object
# word                 petri
# word_norm_post    0.000046
# word_norm_pre          0.0
# diff              0.000046
# Name: 3806, dtype: object
# word              takatalvi
# word_norm_post     0.000046
# word_norm_pre           0.0
# diff               0.000046
# Name: 5064, dtype: object
# word               hyötyjä
# word_norm_post    0.000112
# word_norm_pre     0.000068
# diff              0.000044
# Name: 1140, dtype: object
# word                 varsi
# word_norm_post    0.000254
# word_norm_pre     0.000211
# diff              0.000043
# Name: 6117, dtype: object
# word                 lastu
# word_norm_post    0.000042
# word_norm_pre          0.0
# diff              0.000042
# Name: 2483, dtype: object
# word              eu-ministerivaliokunta
# word_norm_post                  0.000042
# word_norm_pre                        0.0
# diff                            0.000042
# Name: 725, dtype: object
# word               keittää
# word_norm_post    0.000042
# word_norm_pre          0.0
# diff              0.000042
# Name: 1732, dtype: object
# word              viitekorko
# word_norm_post      0.000042
# word_norm_pre            0.0
# diff                0.000042
# Name: 6326, dtype: object
# word              kasvupaketti
# word_norm_post        0.000094
# word_norm_pre         0.000052
# diff                  0.000041
# Name: 1647, dtype: object
# word              keskittynyt
# word_norm_post       0.000052
# word_norm_pre         0.00001
# diff                 0.000041
# Name: 1787, dtype: object
# word               itäraja
# word_norm_post    0.001251
# word_norm_pre      0.00121
# diff              0.000041
# Name: 1331, dtype: object
# word              verotuloarvio
# word_norm_post         0.000082
# word_norm_pre          0.000041
# diff                   0.000041
# Name: 6236, dtype: object
# word              aikalainen
# word_norm_post      0.000128
# word_norm_pre       0.000087
# diff                 0.00004
# Name: 40, dtype: object
# word              keskittämispolitiikka
# word_norm_post                 0.000061
# word_norm_pre                  0.000021
# diff                            0.00004
# Name: 1790, dtype: object
# word              järkeenkäypä
# word_norm_post        0.000046
# word_norm_pre         0.000006
# diff                  0.000039
# Name: 1476, dtype: object
# word              esittelypuhe
# word_norm_post        0.000079
# word_norm_pre         0.000041
# diff                  0.000038
# Name: 679, dtype: object
# word                 jäämä
# word_norm_post    0.000079
# word_norm_pre     0.000042
# diff              0.000037
# Name: 1499, dtype: object
# word              saimaannorppa
# word_norm_post         0.000058
# word_norm_pre          0.000021
# diff                   0.000037
# Name: 4491, dtype: object
# word              kotipesä
# word_norm_post    0.000058
# word_norm_pre     0.000021
# diff              0.000037
# Name: 2089, dtype: object
# word              todistelu
# word_norm_post     0.000067
# word_norm_pre      0.000031
# diff               0.000036
# Name: 5355, dtype: object
# word              turkistarhaus
# word_norm_post         0.000076
# word_norm_pre          0.000041
# diff                   0.000035
# Name: 5565, dtype: object
# word                 lähin
# word_norm_post    0.000191
# word_norm_pre     0.000155
# diff              0.000035
# Name: 2738, dtype: object
# word              puuhailla
# word_norm_post     0.000046
# word_norm_pre       0.00001
# diff               0.000035
# Name: 4067, dtype: object
# word              puhdistaminen
# word_norm_post         0.000046
# word_norm_pre           0.00001
# diff                   0.000035
# Name: 4001, dtype: object
# word              keskushallinto
# word_norm_post            0.0001
# word_norm_pre           0.000065
# diff                    0.000035
# Name: 1794, dtype: object
# word                 bonus
# word_norm_post    0.000061
# word_norm_pre     0.000026
# diff              0.000034
# Name: 357, dtype: object
# word              kansainvälistää
# word_norm_post           0.000064
# word_norm_pre             0.00003
# diff                     0.000034
# Name: 1575, dtype: object
# word              pankkijärjestelmä
# word_norm_post             0.000042
# word_norm_pre               0.00001
# diff                       0.000032
# Name: 3651, dtype: object
# word              edistämiskeskus
# word_norm_post           0.000042
# word_norm_pre             0.00001
# diff                     0.000032
# Name: 426, dtype: object
# word              suurpetopolitiikka
# word_norm_post              0.000036
# word_norm_pre               0.000005
# diff                        0.000031
# Name: 4916, dtype: object
# word              höpöpuhe
# word_norm_post    0.000036
# word_norm_pre     0.000005
# diff              0.000031
# Name: 1176, dtype: object
# word                muutto
# word_norm_post    0.000106
# word_norm_pre     0.000075
# diff              0.000031
# Name: 3137, dtype: object
# word              jugoslavia
# word_norm_post       0.00003
# word_norm_pre            0.0
# diff                 0.00003
# Name: 1414, dtype: object
# word                ettää
# word_norm_post    0.00003
# word_norm_pre         0.0
# diff              0.00003
# Name: 710, dtype: object
# word              grillikioski
# word_norm_post         0.00003
# word_norm_pre              0.0
# diff                   0.00003
# Name: 806, dtype: object
# word              opiskelija-asuminen
# word_norm_post                0.00003
# word_norm_pre                     0.0
# diff                          0.00003
# Name: 3468, dtype: object
# word              hahmottua
# word_norm_post     0.000058
# word_norm_pre      0.000027
# diff                0.00003
# Name: 822, dtype: object
# word                  esim
# word_norm_post    0.000152
# word_norm_pre     0.000122
# diff               0.00003
# Name: 674, dtype: object
# word                   fem
# word_norm_post    0.000091
# word_norm_pre     0.000062
# diff              0.000029
# Name: 753, dtype: object
# word              työjärjestö
# word_norm_post       0.000061
# word_norm_pre        0.000031
# diff                 0.000029
# Name: 5644, dtype: object
# word                 hiven
# word_norm_post    0.000106
# word_norm_pre     0.000078
# diff              0.000028
# Name: 1014, dtype: object
# word              pihlajanmarja
# word_norm_post         0.000042
# word_norm_pre          0.000015
# diff                   0.000027
# Name: 3835, dtype: object
# word              kauppaketju
# word_norm_post       0.000058
# word_norm_pre        0.000031
# diff                 0.000026
# Name: 1694, dtype: object
# word              akateeminen
# word_norm_post       0.000304
# word_norm_pre        0.000278
# diff                 0.000026
# Name: 78, dtype: object
# word              yk-viikko
# word_norm_post     0.000036
# word_norm_pre       0.00001
# diff               0.000026
# Name: 6564, dtype: object
# word              huomenlahja
# word_norm_post       0.000036
# word_norm_pre         0.00001
# diff                 0.000026
# Name: 1089, dtype: object
# word              katsomusaine
# word_norm_post        0.000046
# word_norm_pre          0.00002
# diff                  0.000025
# Name: 1665, dtype: object
# word              rauhanomainen
# word_norm_post         0.000064
# word_norm_pre          0.000039
# diff                   0.000025
# Name: 4315, dtype: object
# word              kultakaivos
# word_norm_post       0.000085
# word_norm_pre         0.00006
# diff                 0.000025
# Name: 2178, dtype: object
# word               laatija
# word_norm_post    0.000091
# word_norm_pre     0.000067
# diff              0.000024
# Name: 2391, dtype: object
# word              keskushermosto
# word_norm_post          0.000042
# word_norm_pre           0.000019
# diff                    0.000024
# Name: 1795, dtype: object
# word              hallintopalatsi
# word_norm_post           0.000042
# word_norm_pre            0.000019
# diff                     0.000023
# Name: 847, dtype: object
# word                tupata
# word_norm_post    0.000155
# word_norm_pre     0.000132
# diff              0.000023
# Name: 5560, dtype: object
# word              kanneoikeus
# word_norm_post       0.000042
# word_norm_pre        0.000019
# diff                 0.000023
# Name: 1564, dtype: object
# word              liikkuja
# word_norm_post    0.000042
# word_norm_pre      0.00002
# diff              0.000022
# Name: 2554, dtype: object
# word              prosenttinen
# word_norm_post        0.000064
# word_norm_pre         0.000042
# diff                  0.000022
# Name: 3990, dtype: object
# word              kulttuuripuoli
# word_norm_post          0.000064
# word_norm_pre           0.000042
# diff                    0.000022
# Name: 2185, dtype: object
# word              käyttötapa
# word_norm_post      0.000064
# word_norm_pre       0.000042
# diff                0.000022
# Name: 2359, dtype: object
# word                 yöuni
# word_norm_post    0.000042
# word_norm_pre     0.000021
# diff              0.000021
# Name: 6685, dtype: object
# word              sinivalkoinen
# word_norm_post         0.000042
# word_norm_pre          0.000021
# diff                   0.000021
# Name: 4671, dtype: object
# word              hankintaprosessi
# word_norm_post            0.000042
# word_norm_pre             0.000021
# diff                      0.000021
# Name: 876, dtype: object
# word                vasara
# word_norm_post    0.000042
# word_norm_pre     0.000021
# diff              0.000021
# Name: 6130, dtype: object
# word              puuttuva
# word_norm_post    0.000042
# word_norm_pre     0.000021
# diff              0.000021
# Name: 4078, dtype: object
# word                myöden
# word_norm_post    0.000052
# word_norm_pre      0.00003
# diff              0.000021
# Name: 3147, dtype: object
# word              eurovaluutta
# word_norm_post        0.000021
# word_norm_pre              0.0
# diff                  0.000021
# Name: 740, dtype: object
# word               lasinen
# word_norm_post    0.000021
# word_norm_pre          0.0
# diff              0.000021
# Name: 2475, dtype: object
# word              loppuaika
# word_norm_post     0.000021
# word_norm_pre           0.0
# diff               0.000021
# Name: 2625, dtype: object
# word              moraaliton
# word_norm_post      0.000021
# word_norm_pre            0.0
# diff                0.000021
# Name: 3075, dtype: object
# word              arkistointi
# word_norm_post       0.000021
# word_norm_pre             0.0
# diff                 0.000021
# Name: 206, dtype: object
# word              alennusesitys
# word_norm_post         0.000021
# word_norm_pre               0.0
# diff                   0.000021
# Name: 104, dtype: object
# word              sanatarkka
# word_norm_post      0.000021
# word_norm_pre            0.0
# diff                0.000021
# Name: 4537, dtype: object
# word              tutkimusmaailma
# word_norm_post           0.000021
# word_norm_pre                 0.0
# diff                     0.000021
# Name: 5599, dtype: object
# word              tarvitsema
# word_norm_post      0.000021
# word_norm_pre            0.0
# diff                0.000021
# Name: 5155, dtype: object
# word              kannustettavuus
# word_norm_post           0.000021
# word_norm_pre                 0.0
# diff                     0.000021
# Name: 1568, dtype: object
# word              kannanmuodostus
# word_norm_post           0.000021
# word_norm_pre                 0.0
# diff                     0.000021
# Name: 1553, dtype: object
# word              ruokaketju
# word_norm_post      0.000021
# word_norm_pre            0.0
# diff                0.000021
# Name: 4442, dtype: object
# word              kunnianarvoisa
# word_norm_post          0.000021
# word_norm_pre                0.0
# diff                    0.000021
# Name: 2215, dtype: object
# word                päinen
# word_norm_post    0.000021
# word_norm_pre          0.0
# diff              0.000021
# Name: 4106, dtype: object
# word                 pilke
# word_norm_post    0.000021
# word_norm_pre          0.0
# diff              0.000021
# Name: 3857, dtype: object
# word              kuvatallenne
# word_norm_post        0.000021
# word_norm_pre              0.0
# diff                  0.000021
# Name: 2286, dtype: object
# word              lähikoulu
# word_norm_post     0.000021
# word_norm_pre           0.0
# diff               0.000021
# Name: 2736, dtype: object
# word                notkua
# word_norm_post    0.000021
# word_norm_pre          0.0
# diff              0.000021
# Name: 3262, dtype: object
# word                 nykiä
# word_norm_post    0.000021
# word_norm_pre          0.0
# diff              0.000021
# Name: 3284, dtype: object
# word              mustasalkkuinen
# word_norm_post           0.000021
# word_norm_pre                 0.0
# diff                     0.000021
# Name: 3117, dtype: object
# word              työllisyyskeskustelu
# word_norm_post                0.000021
# word_norm_pre                      0.0
# diff                          0.000021
# Name: 5665, dtype: object
# word                  arpa
# word_norm_post    0.000021
# word_norm_pre          0.0
# diff              0.000021
# Name: 211, dtype: object
# word              valtiojohto
# word_norm_post       0.000021
# word_norm_pre             0.0
# diff                 0.000021
# Name: 6018, dtype: object
# word              häthätää
# word_norm_post    0.000021
# word_norm_pre          0.0
# diff              0.000021
# Name: 1166, dtype: object
# word              rikosoikeudenkäynti
# word_norm_post               0.000021
# word_norm_pre                     0.0
# diff                         0.000021
# Name: 4394, dtype: object
# word              kohtapuoliin
# word_norm_post         0.00003
# word_norm_pre         0.000009
# diff                  0.000021
# Name: 1957, dtype: object
# word              luonnontila
# word_norm_post        0.00003
# word_norm_pre         0.00001
# diff                  0.00002
# Name: 2674, dtype: object
# word              hallitusohjelmakeskustelu
# word_norm_post                      0.00003
# word_norm_pre                       0.00001
# diff                                0.00002
# Name: 857, dtype: object
# word              kustannuskilpailukykyongelma
# word_norm_post                         0.00003
# word_norm_pre                          0.00001
# diff                                   0.00002
# Name: 2255, dtype: object
# word              räjäyttää
# word_norm_post      0.00003
# word_norm_pre       0.00001
# diff                0.00002
# Name: 4463, dtype: object
# word              fiskaalisesti
# word_norm_post          0.00003
# word_norm_pre           0.00001
# diff                    0.00002
# Name: 769, dtype: object
# word                 päre
# word_norm_post    0.00003
# word_norm_pre     0.00001
# diff              0.00002
# Name: 4124, dtype: object
# word               loputon
# word_norm_post    0.000206
# word_norm_pre     0.000186
# diff              0.000019
# Name: 2635, dtype: object
# word              väärinkäyttö
# word_norm_post        0.000122
# word_norm_pre         0.000102
# diff                  0.000019
# Name: 6491, dtype: object
# word              katsomustieto
# word_norm_post         0.000076
# word_norm_pre          0.000057
# diff                   0.000019
# Name: 1666, dtype: object
# word              pystyttää
# word_norm_post     0.000064
# word_norm_pre      0.000045
# diff               0.000019
# Name: 4084, dtype: object
# word              kemikaalivirasto
# word_norm_post            0.000061
# word_norm_pre             0.000043
# diff                      0.000018
# Name: 1743, dtype: object
# word              yleislääkäri
# word_norm_post        0.000042
# word_norm_pre         0.000025
# diff                  0.000017
# Name: 6612, dtype: object
# word              koivisto
# word_norm_post    0.000036
# word_norm_pre      0.00002
# diff              0.000016
# Name: 1970, dtype: object
# word              yksityistalous
# word_norm_post           0.00003
# word_norm_pre           0.000014
# diff                    0.000016
# Name: 6602, dtype: object
# word              teollisuuspolitiikka
# word_norm_post                0.000042
# word_norm_pre                 0.000026
# diff                          0.000016
# Name: 5231, dtype: object
# word              eläinsuojeluvaltuutettu
# word_norm_post                   0.000061
# word_norm_pre                    0.000045
# diff                             0.000016
# Name: 520, dtype: object
# word              tietojensaantioikeus
# word_norm_post                0.000058
# word_norm_pre                 0.000042
# diff                          0.000016
# Name: 5293, dtype: object
# word              näennäinen
# word_norm_post      0.000042
# word_norm_pre       0.000027
# diff                0.000016
# Name: 3298, dtype: object
# word              kulttuurielämä
# word_norm_post          0.000036
# word_norm_pre           0.000021
# diff                    0.000015
# Name: 2181, dtype: object
# word                 ohjus
# word_norm_post    0.000036
# word_norm_pre     0.000021
# diff              0.000015
# Name: 3343, dtype: object
# word              heikentävä
# word_norm_post      0.000036
# word_norm_pre       0.000021
# diff                0.000015
# Name: 931, dtype: object
# word              epäyhtenäinen
# word_norm_post         0.000015
# word_norm_pre               0.0
# diff                   0.000015
# Name: 630, dtype: object
# word              ammattiliittojohtaja
# word_norm_post                0.000015
# word_norm_pre                      0.0
# diff                          0.000015
# Name: 170, dtype: object
# word              raolleen
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 4285, dtype: object
# word              työskenteleminen
# word_norm_post            0.000015
# word_norm_pre                  0.0
# diff                      0.000015
# Name: 5706, dtype: object
# word              työnäyte
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 5697, dtype: object
# word              fundamentti
# word_norm_post       0.000015
# word_norm_pre             0.0
# diff                 0.000015
# Name: 785, dtype: object
# word              epäyhdenvertaisuus
# word_norm_post              0.000015
# word_norm_pre                    0.0
# diff                        0.000015
# Name: 629, dtype: object
# word               förstås
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 794, dtype: object
# word              kotiäiti
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 2093, dtype: object
# word              kourallinen
# word_norm_post       0.000015
# word_norm_pre             0.0
# diff                 0.000015
# Name: 2125, dtype: object
# word              isänpäivä
# word_norm_post     0.000015
# word_norm_pre           0.0
# diff               0.000015
# Name: 1312, dtype: object
# word              korporaatio
# word_norm_post       0.000015
# word_norm_pre             0.0
# diff                 0.000015
# Name: 2063, dtype: object
# word              jalkautua
# word_norm_post     0.000015
# word_norm_pre           0.0
# diff               0.000015
# Name: 1342, dtype: object
# word              röntgenhoitaja
# word_norm_post          0.000015
# word_norm_pre                0.0
# diff                    0.000015
# Name: 4466, dtype: object
# word               korkeus
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 2053, dtype: object
# word              kantatie
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 1604, dtype: object
# word              sirpalemaisuus
# word_norm_post          0.000015
# word_norm_pre                0.0
# diff                    0.000015
# Name: 4679, dtype: object
# word              sopeuttamistarve
# word_norm_post            0.000015
# word_norm_pre                  0.0
# diff                      0.000015
# Name: 4752, dtype: object
# word              pitemmälle
# word_norm_post      0.000015
# word_norm_pre            0.0
# diff                0.000015
# Name: 3865, dtype: object
# word              liiketoimintaympäristö
# word_norm_post                  0.000015
# word_norm_pre                        0.0
# diff                            0.000015
# Name: 2549, dtype: object
# word              moninaistuminen
# word_norm_post           0.000015
# word_norm_pre                 0.0
# diff                     0.000015
# Name: 3064, dtype: object
# word              mallikkaasti
# word_norm_post        0.000015
# word_norm_pre              0.0
# diff                  0.000015
# Name: 2872, dtype: object
# word              maailmanjärjestö
# word_norm_post            0.000015
# word_norm_pre                  0.0
# diff                      0.000015
# Name: 2799, dtype: object
# word                mairea
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 2852, dtype: object
# word                arkuus
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 208, dtype: object
# word              opetustila
# word_norm_post      0.000015
# word_norm_pre            0.0
# diff                0.000015
# Name: 3462, dtype: object
# word              raasepori
# word_norm_post     0.000015
# word_norm_pre           0.0
# diff               0.000015
# Name: 4204, dtype: object
# word              päällystakki
# word_norm_post        0.000015
# word_norm_pre              0.0
# diff                  0.000015
# Name: 4146, dtype: object
# word              pysäyttävä
# word_norm_post      0.000015
# word_norm_pre            0.0
# diff                0.000015
# Name: 4091, dtype: object
# word              rajahyöty
# word_norm_post     0.000015
# word_norm_pre           0.0
# diff               0.000015
# Name: 4234, dtype: object
# word               paltamo
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 3636, dtype: object
# word              peruskorjausraha
# word_norm_post            0.000015
# word_norm_pre                  0.0
# diff                      0.000015
# Name: 3751, dtype: object
# word              vähimmäispelisääntö
# word_norm_post               0.000015
# word_norm_pre                     0.0
# diff                         0.000015
# Name: 6431, dtype: object
# word               penseys
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 3719, dtype: object
# word              kuntoilla
# word_norm_post     0.000015
# word_norm_pre           0.0
# diff               0.000015
# Name: 2237, dtype: object
# word                puikko
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 4013, dtype: object
# word              määräävä
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 3182, dtype: object
# word              yliarvioida
# word_norm_post       0.000015
# word_norm_pre             0.0
# diff                 0.000015
# Name: 6622, dtype: object
# word              oppimateriaalikysymys
# word_norm_post                 0.000015
# word_norm_pre                       0.0
# diff                           0.000015
# Name: 3479, dtype: object
# word              palkannauttija
# word_norm_post          0.000015
# word_norm_pre                0.0
# diff                    0.000015
# Name: 3615, dtype: object
# word              porvaristo
# word_norm_post      0.000015
# word_norm_pre            0.0
# diff                0.000015
# Name: 3959, dtype: object
# word                cooper
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 380, dtype: object
# word                 haara
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 810, dtype: object
# word              grundläggande
# word_norm_post         0.000015
# word_norm_pre               0.0
# diff                   0.000015
# Name: 807, dtype: object
# word                genast
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 797, dtype: object
# word              valintajärjestelmä
# word_norm_post              0.000015
# word_norm_pre                    0.0
# diff                        0.000015
# Name: 5974, dtype: object
# word              viestintäverkko
# word_norm_post           0.000015
# word_norm_pre                 0.0
# diff                     0.000015
# Name: 6293, dtype: object
# word              velkavuori
# word_norm_post      0.000015
# word_norm_pre            0.0
# diff                0.000015
# Name: 6191, dtype: object
# word               haukata
# word_norm_post    0.000015
# word_norm_pre          0.0
# diff              0.000015
# Name: 915, dtype: object
# word              tukahduttaminen
# word_norm_post           0.000015
# word_norm_pre                 0.0
# diff                     0.000015
# Name: 5464, dtype: object
# word                 hapan
# word_norm_post    0.000042
# word_norm_pre     0.000028
# diff              0.000014
# Name: 883, dtype: object
# word              huippuosaama
# word_norm_post        0.000052
# word_norm_pre         0.000038
# diff                  0.000014
# Name: 1054, dtype: object
# word              korkeakoulutettu
# word_norm_post             0.00003
# word_norm_pre             0.000017
# diff                      0.000013
# Name: 2047, dtype: object
# word              paperityö
# word_norm_post     0.000058
# word_norm_pre      0.000046
# diff               0.000012
# Name: 3660, dtype: object
# word              tillväxt
# word_norm_post    0.000122
# word_norm_pre      0.00011
# diff              0.000011
# Name: 5332, dtype: object
# word                   luo
# word_norm_post    0.000085
# word_norm_pre     0.000073
# diff              0.000011
# Name: 2660, dtype: object
# word                ruanda
# word_norm_post    0.000021
# word_norm_pre      0.00001
# diff              0.000011
# Name: 4433, dtype: object
# word               harveta
# word_norm_post    0.000042
# word_norm_pre     0.000031
# diff              0.000011
# Name: 909, dtype: object
# word              palkkavero
# word_norm_post      0.000021
# word_norm_pre        0.00001
# diff                0.000011
# Name: 3632, dtype: object
# word                louhia
# word_norm_post    0.000021
# word_norm_pre      0.00001
# diff              0.000011
# Name: 2637, dtype: object
# word              yksittäin
# word_norm_post     0.000021
# word_norm_pre       0.00001
# diff               0.000011
# Name: 6592, dtype: object
# word              kompensoima
# word_norm_post       0.000021
# word_norm_pre         0.00001
# diff                 0.000011
# Name: 2011, dtype: object
# word              arvioima
# word_norm_post    0.000021
# word_norm_pre      0.00001
# diff              0.000011
# Name: 221, dtype: object
# word              taloussuhde
# word_norm_post       0.000021
# word_norm_pre         0.00001
# diff                 0.000011
# Name: 5091, dtype: object
# word              suvereeni
# word_norm_post     0.000021
# word_norm_pre       0.00001
# diff               0.000011
# Name: 4923, dtype: object
# word                 sisar
# word_norm_post    0.000021
# word_norm_pre      0.00001
# diff              0.000011
# Name: 4680, dtype: object
# word              valmisteleva
# word_norm_post        0.000021
# word_norm_pre          0.00001
# diff                  0.000011
# Name: 5996, dtype: object
# word                uneton
# word_norm_post    0.000021
# word_norm_pre      0.00001
# diff              0.000011
# Name: 5827, dtype: object
# word              turvallisuuskysymys
# word_norm_post               0.000021
# word_norm_pre                 0.00001
# diff                         0.000011
# Name: 5575, dtype: object
# word              avolaitos
# word_norm_post     0.000021
# word_norm_pre       0.00001
# diff               0.000011
# Name: 334, dtype: object
# word              moottoritie
# word_norm_post       0.000021
# word_norm_pre         0.00001
# diff                 0.000011
# Name: 3072, dtype: object
# word              vertautua
# word_norm_post     0.000021
# word_norm_pre       0.00001
# diff               0.000011
# Name: 6252, dtype: object
# word              virkavalmistelu
# word_norm_post           0.000021
# word_norm_pre             0.00001
# diff                     0.000011
# Name: 6362, dtype: object
# word              voimasuhde
# word_norm_post      0.000021
# word_norm_pre        0.00001
# diff                0.000011
# Name: 6382, dtype: object
# word              voimistaa
# word_norm_post     0.000021
# word_norm_pre       0.00001
# diff               0.000011
# Name: 6384, dtype: object
# word              perusoikeuskysymys
# word_norm_post              0.000021
# word_norm_pre                0.00001
# diff                        0.000011
# Name: 3754, dtype: object
# word              kulttuuritoiminta
# word_norm_post             0.000021
# word_norm_pre               0.00001
# diff                       0.000011
# Name: 2186, dtype: object
# word               viipymä
# word_norm_post    0.000021
# word_norm_pre      0.00001
# diff              0.000011
# Name: 6318, dtype: object
# word              yhdeksäs
# word_norm_post    0.000021
# word_norm_pre      0.00001
# diff              0.000011
# Name: 6507, dtype: object
# word              valokuva
# word_norm_post    0.000021
# word_norm_pre      0.00001
# diff              0.000011
# Name: 6006, dtype: object
# word              enimmäispituus
# word_norm_post          0.000021
# word_norm_pre            0.00001
# diff                    0.000011
# Name: 564, dtype: object
# word              katsomus
# word_norm_post    0.000015
# word_norm_pre     0.000005
# diff               0.00001
# Name: 1664, dtype: object
# word              funktionaalinen
# word_norm_post           0.000015
# word_norm_pre            0.000005
# diff                      0.00001
# Name: 786, dtype: object
# word              buddhalaisuus
# word_norm_post         0.000015
# word_norm_pre          0.000005
# diff                    0.00001
# Name: 363, dtype: object
# word              uskontotieto
# word_norm_post        0.000015
# word_norm_pre         0.000005
# diff                   0.00001
# Name: 5859, dtype: object
# word              valtauskonto
# word_norm_post        0.000015
# word_norm_pre         0.000005
# diff                   0.00001
# Name: 6014, dtype: object
# word              tapailla
# word_norm_post    0.000015
# word_norm_pre     0.000005
# diff               0.00001
# Name: 5106, dtype: object
# word              mandealaisuus
# word_norm_post         0.000015
# word_norm_pre          0.000005
# diff                    0.00001
# Name: 2879, dtype: object
# word              saaristomeri
# word_norm_post        0.000061
# word_norm_pre         0.000051
# diff                   0.00001
# Name: 4477, dtype: object
# word              maailmanhistoria
# word_norm_post            0.000021
# word_norm_pre             0.000011
# diff                       0.00001
# Name: 2798, dtype: object
# word              suupieli
# word_norm_post    0.000021
# word_norm_pre     0.000011
# diff               0.00001
# Name: 4911, dtype: object
# word              porrastaminen
# word_norm_post          0.00003
# word_norm_pre          0.000021
# diff                   0.000009
# Name: 3952, dtype: object
# word              keventyä
# word_norm_post     0.00003
# word_norm_pre     0.000021
# diff              0.000009
# Name: 1816, dtype: object
# word              palkkatukijakso
# word_norm_post            0.00003
# word_norm_pre            0.000021
# diff                     0.000009
# Name: 3630, dtype: object
# word                export
# word_norm_post    0.000015
# word_norm_pre     0.000006
# diff              0.000009
# Name: 746, dtype: object
# word                 juoma
# word_norm_post    0.000109
# word_norm_pre       0.0001
# diff              0.000009
# Name: 1432, dtype: object
# word                  cent
# word_norm_post    0.000015
# word_norm_pre     0.000007
# diff              0.000009
# Name: 378, dtype: object
# word              vapausoikeus
# word_norm_post        0.000015
# word_norm_pre         0.000007
# diff                  0.000009
# Name: 6082, dtype: object
# word                 kissa
# word_norm_post    0.000158
# word_norm_pre      0.00015
# diff              0.000008
# Name: 1914, dtype: object
# word              kirjailija
# word_norm_post      0.000094
# word_norm_pre       0.000086
# diff                0.000008
# Name: 1900, dtype: object
# word              piensijoittaja
# word_norm_post          0.000021
# word_norm_pre           0.000013
# diff                    0.000008
# Name: 3830, dtype: object
# word               murunen
# word_norm_post    0.000064
# word_norm_pre     0.000057
# diff              0.000007
# Name: 3113, dtype: object
# word              kauhavalainen
# word_norm_post         0.000015
# word_norm_pre          0.000009
# diff                   0.000006
# Name: 1679, dtype: object
# word                 mauno
# word_norm_post    0.000015
# word_norm_pre     0.000009
# diff              0.000006
# Name: 2904, dtype: object
# word              avarakatseisesti
# word_norm_post            0.000015
# word_norm_pre             0.000009
# diff                      0.000006
# Name: 321, dtype: object
# word              evidenssi
# word_norm_post     0.000015
# word_norm_pre      0.000009
# diff               0.000006
# Name: 744, dtype: object
# word              polkumyynti
# word_norm_post       0.000015
# word_norm_pre        0.000009
# diff                 0.000006
# Name: 3934, dtype: object
# word              mahdollistama
# word_norm_post         0.000021
# word_norm_pre          0.000015
# diff                   0.000006
# Name: 2837, dtype: object
# word              sumuttaa
# word_norm_post    0.000021
# word_norm_pre     0.000015
# diff              0.000006
# Name: 4849, dtype: object
# word                 eksyä
# word_norm_post    0.000021
# word_norm_pre     0.000015
# diff              0.000006
# Name: 475, dtype: object
# word              vanhentunut
# word_norm_post       0.000021
# word_norm_pre        0.000015
# diff                 0.000006
# Name: 6060, dtype: object
# word                muisto
# word_norm_post    0.000112
# word_norm_pre     0.000107
# diff              0.000006
# Name: 3089, dtype: object
# word               tieraha
# word_norm_post    0.000042
# word_norm_pre     0.000037
# diff              0.000006
# Name: 5284, dtype: object
# word                 tuomo
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 5537, dtype: object
# word              äidinkieli
# word_norm_post      0.000091
# word_norm_pre       0.000086
# diff                0.000005
# Name: 6687, dtype: object
# word              rakentuminen
# word_norm_post        0.000015
# word_norm_pre          0.00001
# diff                  0.000005
# Name: 4272, dtype: object
# word              naisyrittäjä
# word_norm_post        0.000036
# word_norm_pre         0.000031
# diff                  0.000005
# Name: 3191, dtype: object
# word              alijäämämenettely
# word_norm_post             0.000036
# word_norm_pre              0.000031
# diff                       0.000005
# Name: 113, dtype: object
# word              klausuuli
# word_norm_post     0.000015
# word_norm_pre       0.00001
# diff               0.000005
# Name: 1932, dtype: object
# word                 helen
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 946, dtype: object
# word              varrelle
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 6116, dtype: object
# word              rakentamishanke
# word_norm_post           0.000015
# word_norm_pre             0.00001
# diff                     0.000005
# Name: 4268, dtype: object
# word              ennustus
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 583, dtype: object
# word              hengittää
# word_norm_post     0.000015
# word_norm_pre       0.00001
# diff               0.000005
# Name: 957, dtype: object
# word              informointi
# word_norm_post       0.000015
# word_norm_pre         0.00001
# diff                 0.000005
# Name: 1262, dtype: object
# word               eversti
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 743, dtype: object
# word                 helle
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 947, dtype: object
# word              haaskaaminen
# word_norm_post        0.000015
# word_norm_pre          0.00001
# diff                  0.000005
# Name: 811, dtype: object
# word              verokannustin
# word_norm_post         0.000015
# word_norm_pre           0.00001
# diff                   0.000005
# Name: 6210, dtype: object
# word              epäjärjestys
# word_norm_post        0.000015
# word_norm_pre          0.00001
# diff                  0.000005
# Name: 606, dtype: object
# word              kuukausitolkku
# word_norm_post          0.000015
# word_norm_pre            0.00001
# diff                    0.000005
# Name: 2267, dtype: object
# word              purjehtia
# word_norm_post     0.000015
# word_norm_pre       0.00001
# diff               0.000005
# Name: 4056, dtype: object
# word              postiliikenne
# word_norm_post         0.000015
# word_norm_pre           0.00001
# diff                   0.000005
# Name: 3964, dtype: object
# word              oikeussali
# word_norm_post      0.000015
# word_norm_pre        0.00001
# diff                0.000005
# Name: 3377, dtype: object
# word              rakennekehitys
# word_norm_post          0.000015
# word_norm_pre            0.00001
# diff                    0.000005
# Name: 4255, dtype: object
# word              vihjailla
# word_norm_post     0.000015
# word_norm_pre       0.00001
# diff               0.000005
# Name: 6302, dtype: object
# word                  kato
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 1659, dtype: object
# word              seikkaperäinen
# word_norm_post          0.000015
# word_norm_pre            0.00001
# diff                    0.000005
# Name: 4570, dtype: object
# word                  jyvä
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 1447, dtype: object
# word              sivurooli
# word_norm_post     0.000015
# word_norm_pre       0.00001
# diff               0.000005
# Name: 4726, dtype: object
# word              kansalaisoikeus
# word_norm_post           0.000015
# word_norm_pre             0.00001
# diff                     0.000005
# Name: 1580, dtype: object
# word              rahanmeno
# word_norm_post     0.000015
# word_norm_pre       0.00001
# diff               0.000005
# Name: 4213, dtype: object
# word              opinto-ohjelma
# word_norm_post          0.000015
# word_norm_pre            0.00001
# diff                    0.000005
# Name: 3464, dtype: object
# word                  onki
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 3440, dtype: object
# word              ylitarjonta
# word_norm_post       0.000015
# word_norm_pre         0.00001
# diff                 0.000005
# Name: 6635, dtype: object
# word              läpikotaisin
# word_norm_post        0.000015
# word_norm_pre          0.00001
# diff                  0.000005
# Name: 2768, dtype: object
# word              ideaalinen
# word_norm_post      0.000015
# word_norm_pre        0.00001
# diff                0.000005
# Name: 1178, dtype: object
# word              julmasti
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 1426, dtype: object
# word                 ehtyä
# word_norm_post    0.000015
# word_norm_pre      0.00001
# diff              0.000005
# Name: 463, dtype: object
# word              kiukuttelu
# word_norm_post      0.000015
# word_norm_pre        0.00001
# diff                0.000005
# Name: 1918, dtype: object
# word              älypuhelin
# word_norm_post      0.000042
# word_norm_pre       0.000038
# diff                0.000004
# Name: 6692, dtype: object
# word              porskuttaa
# word_norm_post      0.000021
# word_norm_pre       0.000017
# diff                0.000004
# Name: 3955, dtype: object
# word              silmäkulma
# word_norm_post      0.000021
# word_norm_pre       0.000017
# diff                0.000004
# Name: 4663, dtype: object
# word              leijonanosa
# word_norm_post       0.000021
# word_norm_pre        0.000017
# diff                 0.000004
# Name: 2498, dtype: object
# word              hoitoonpääsy
# word_norm_post         0.00003
# word_norm_pre         0.000026
# diff                  0.000004
# Name: 1027, dtype: object
# word              keskipitkä
# word_norm_post      0.000094
# word_norm_pre        0.00009
# diff                0.000004
# Name: 1782, dtype: object
# word              ylihärmä
# word_norm_post    0.000015
# word_norm_pre     0.000011
# diff              0.000004
# Name: 6624, dtype: object
# word              puolivillainen
# word_norm_post          0.000079
# word_norm_pre           0.000075
# diff                    0.000004
# Name: 4027, dtype: object
# word                  uida
# word_norm_post    0.000058
# word_norm_pre     0.000054
# diff              0.000003
# Name: 5792, dtype: object
# word               ledning
# word_norm_post    0.000076
# word_norm_pre     0.000073
# diff              0.000003
# Name: 2495, dtype: object
# word              iltavuoro
# word_norm_post      0.00003
# word_norm_pre      0.000027
# diff               0.000003
# Name: 1252, dtype: object
# word                   ken
# word_norm_post    0.000021
# word_norm_pre     0.000019
# diff              0.000003
# Name: 1744, dtype: object
# word                kinata
# word_norm_post    0.000036
# word_norm_pre     0.000034
# diff              0.000003
# Name: 1888, dtype: object
# word              tiemestari
# word_norm_post      0.000042
# word_norm_pre        0.00004
# diff                0.000002
# Name: 5281, dtype: object
# word              surrealistinen
# word_norm_post          0.000015
# word_norm_pre           0.000013
# diff                    0.000002
# Name: 4893, dtype: object
# word               haluava
# word_norm_post    0.000015
# word_norm_pre     0.000013
# diff              0.000002
# Name: 867, dtype: object
# word              luonnikas
# word_norm_post     0.000015
# word_norm_pre      0.000013
# diff               0.000002
# Name: 2667, dtype: object
# word              puoluevaltuutettu
# word_norm_post             0.000015
# word_norm_pre              0.000013
# diff                       0.000002
# Name: 4036, dtype: object
# word              budjettiraami
# word_norm_post         0.000021
# word_norm_pre           0.00002
# diff                   0.000001
# Name: 370, dtype: object
# word              vahingonteko
# word_norm_post        0.000021
# word_norm_pre          0.00002
# diff                  0.000001
# Name: 5908, dtype: object
# word              suvereniteetti
# word_norm_post           0.00014
# word_norm_pre           0.000139
# diff                         0.0
# Name: 4924, dtype: object
# word              nykytekniikka
# word_norm_post         0.000015
# word_norm_pre          0.000015
# diff                        0.0
# Name: 3293, dtype: object
# word                 vireä
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 6353, dtype: object
# word              kotimarkkina
# word_norm_post        0.000021
# word_norm_pre         0.000021
# diff                       0.0
# Name: 2085, dtype: object
# word              valvontavirasto
# word_norm_post           0.000021
# word_norm_pre            0.000021
# diff                          0.0
# Name: 6049, dtype: object
# word              lainsäännös
# word_norm_post       0.000021
# word_norm_pre        0.000021
# diff                      0.0
# Name: 2424, dtype: object
# word              mahdollistava
# word_norm_post         0.000021
# word_norm_pre          0.000021
# diff                        0.0
# Name: 2839, dtype: object
# word              kansalaistoiminta
# word_norm_post             0.000021
# word_norm_pre              0.000021
# diff                            0.0
# Name: 1582, dtype: object
# word              näyttävä
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 3317, dtype: object
# word              asiantuntijaselvitys
# word_norm_post                0.000021
# word_norm_pre                 0.000021
# diff                               0.0
# Name: 272, dtype: object
# word                 buumi
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 373, dtype: object
# word              edustava
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 442, dtype: object
# word              syntyperä
# word_norm_post     0.000021
# word_norm_pre      0.000021
# diff                    0.0
# Name: 4941, dtype: object
# word               pyörtää
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 4099, dtype: object
# word              noudatella
# word_norm_post      0.000021
# word_norm_pre       0.000021
# diff                     0.0
# Name: 3263, dtype: object
# word                pitävä
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 3884, dtype: object
# word              turvavyö
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 5591, dtype: object
# word              investointihalu
# word_norm_post           0.000021
# word_norm_pre            0.000021
# diff                          0.0
# Name: 1288, dtype: object
# word              erityisosaaja
# word_norm_post         0.000021
# word_norm_pre          0.000021
# diff                        0.0
# Name: 658, dtype: object
# word              päiväkoti-ikäinen
# word_norm_post             0.000021
# word_norm_pre              0.000021
# diff                            0.0
# Name: 4119, dtype: object
# word              entisellään
# word_norm_post       0.000021
# word_norm_pre        0.000021
# diff                      0.0
# Name: 596, dtype: object
# word              suljettu
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 4843, dtype: object
# word              sikäläinen
# word_norm_post      0.000021
# word_norm_pre       0.000021
# diff                     0.0
# Name: 4658, dtype: object
# word              oulainen
# word_norm_post    0.000021
# word_norm_pre     0.000021
# diff                   0.0
# Name: 3539, dtype: object
# word              kyvykkyys
# word_norm_post     0.000015
# word_norm_pre      0.000015
# diff                    0.0
# Name: 2320, dtype: object
# word                 natur
# word_norm_post    0.000015
# word_norm_pre     0.000015
# diff                   0.0
# Name: 3196, dtype: object
# word              ålandsminister
# word_norm_post          0.000015
# word_norm_pre           0.000015
# diff                         0.0
# Name: 6713, dtype: object

# %% [markdown]
# *ANALYSIS* LEMMATISED FILTERED
#
# Check in which contexts the words that have a higher sum of normalised frequency in 2024-2025 than in 2015-2023 appear. This means connecting them with data from the original content: the lemmatised speeches.
#
# Below the words are linked to the speeches and added as a list of matched words. This is to help with analysis.

# %%
# next: "{directory}/csv_analysis/speeches_combined_plus_length_lemma.csv"
# check in which contexts (content_lemmatized) these words have been used -> extract content_lemmatized if words exists there -> check what kinds of sentences these match (content)
df_all_speeches = pd.read_csv(f'{directory}/csv_analysis/filtered/speeches_combined_plus_length_lemma.csv', sep=';', header=0, dtype='str')
df_all_speeches['year'] = pd.to_numeric(df_all_speeches['year'], downcast='integer')
df_all_speeches['n_words_in_speech'] = pd.to_numeric(df_all_speeches['n_words_in_speech'], downcast='integer')
pattern = '|'.join(compare_word_norm_sums['word'].astype(str))
df_filtered = df_all_speeches[df_all_speeches['content_lemmatized'].str.contains(pattern, case=False, na=False)]

# now filtered. next: which words of compare_word_norm_sums['word'] appear in the speech, store in new column
words_set = set(compare_word_norm_sums['word'].dropna().unique())
df_filtered = df_filtered.copy()
df_filtered.loc[:, 'filter_words'] = df_filtered['content_lemmatized'].apply(lambda x: ','.join([i for i in x.split() if i in words_set]) if isinstance(x, str) else None)

# keep rows of df_filtered where len('filter_words') > 0
df_filtered = df_filtered[df_filtered['filter_words'].str.len()>0]

# %%
# demonstrate what df_filtered contains
df_filtered.head(1).T
# Out:
#                                                                        19
# speech_id                                                        2015_4_8
# session                                                            4/2015
# date                                                           2015-05-12
# start_time                                                           14.0
# end_time                                                            15.07
# given                                                               Antti
# family                                                          Kaikkonen
# role                                                       Kansanedustaja
# party                                                                KESK
# topic                   Euroopan neuvoston  Suomen valtuuskunnan kerto...
# content                  Arvoisa puhemies! Euroopan neuvosto on merkit...
# speech_type                                                   Puheenvuoro
# mp_uri                                  http://ldf.fi/semparl/people/p772
# gender                                                               Male
# birth                                                          1974-01-01
# party_uri                            http://ldf.fi/semparl/groups/Q506591
# parliamentary_role                                        Oppositiopuolue
# group_uri               http://ldf.fi/semparl/groups/g3152040749812589813
# status                                                             Valmis
# version                                                               5.1
# link                    https://www.eduskunta.fi/FI/vaski/PoytakirjaAs...
# lang                                                                   fi
# name_in_source                                            Antti Kaikkonen
# speaker_id                                                            772
# speech_start                                          2015-05-12T14:18:16
# speech_end                                            2015-05-12T14:20:21
# speech_status                                                 Tarkistettu
# speech_version                                                        1.1
# url                        http://ldf.fi/semparl/speeches/s2015_1_004_008
# content_lemmatized      arvoisa puhemies ! Eurooppa neuvosto olla merk...
# content_lemmatized_pos  arvoisa//ADJ puhemies//NOUN !//PUNCT Eurooppa/...
# year                                                                 2015
# n_words_in_speech                                                     222
# filter_words                                                        toivo
