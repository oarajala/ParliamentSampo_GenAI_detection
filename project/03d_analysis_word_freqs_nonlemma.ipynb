# %%
# import packages, declare constants, get the parent directory
import pandas as pd
import numpy as np
import re
import os
import time
import decimal
from scipy import stats
#from wordcloud import WordCloud
import matplotlib.pyplot as plt
from matplotlib import colormaps
#from .utils import helpers
#import simplemma
import pyvoikko

CHATGPT_RELEASE_YEAR = int(2022)
FINNISH_ALPHABET = 'abcdefghijklmnopqrstuvwxyzåäö'

def get_parent_directory() -> str:
    """Get the parent directory for handling csv files.

    Returns:
        string: the path to the directory where directories for csv files are located
    """
    #create relative path for parent
    relative_parent = os.path.join(os.getcwd(), '..')

    #use abspath for absolute parent path
    return str(os.path.abspath(relative_parent)).replace('\\', '/')

directory = get_parent_directory()

# %% [markdown]
# DECLARE FUNCTIONS

# %%
def clean_string(string: str) -> str:
    try:
        # remove blanks in start and end
        string = string.strip()
        string = string.lower()
        # the string must contain characters
        if any(c in string for c in FINNISH_ALPHABET)==False:
            string = ''
        # remove tabulations, line breaks etc., also special characters
        remove_these = r'[\+\*!"”’?.:,…()§\'[\] \t\n\r\f\v]'
        string = re.sub(remove_these, '', string)
        # remove weird parentheses and backwards linebreaks from starts of strings
        string = re.sub(r'^\)\\[a-z]', '', string)
        # remove weird '\[alphabet]' strings at start of strings
        string = re.sub(r'^\\[a-z]', '', string)
        # remove numbers
        string = re.sub(r'[0-9]', '', string)
        # remove dashes '-' at the start and end of string
        string = re.sub(r'^-|-$', '', string)
        # remove individual forward and backward slashes '/', '\'
        string = re.sub(r'[\/\\]', '', string)
        # remove double dashes '--'
        string = string.replace('--', '-')
        # remove the equal sign '='
        string = string.replace('=', '')
        # at the end of the cleaning, remove all characters from the string which are not in the alphabet except for dash (compound words)
        remove_these = ''.join([str(c) for c in string if c != '-' and c not in [i for i in FINNISH_ALPHABET]])
        string = re.sub(remove_these, '', string)
        # remove blanks in start and end again
        string = string.strip()
        # remove empty if string length < 2
        string = '' if len(string) < 2 else string
        return string
    except:
        print(f'Unexpected error at helpers.clean_string(), string: {string}')
        raise

# %%
def count_word_freqs_in_string(string: str):
    """Counts the words in the input string.
    Returns a dictionary where the word is the key and the frequency is the value.
    """
    if ((string is None) or (string == 'nan')):
        return None
    else:
        words_list = re.split(' ', string)
        wordfreq_dict = {}
        for word in words_list:
            if word not in wordfreq_dict.keys():
                wordfreq_dict[word] = 1
            else:
                wordfreq_dict[word] += 1

        return wordfreq_dict

# %%
def get_normalised(df: pd.DataFrame, speaker_id: str, year: int, word_n: int) -> float:
    w_min = df['word_n'].loc[(df['speaker_id']==speaker_id)&(df['year']==year)].min()
    w_max = df['word_n'].loc[(df['speaker_id']==speaker_id)&(df['year']==year)].max()
    return ((word_n-w_min)/(w_max-w_min))

# %%
def linear_extrapolation(y: list, x: list, n=1) -> list:
    """Linear extrapolation based on last two x and y observations. Returns the extrapolated value of y for a given x based on y1x1 and y2x2.
    Parameter x will be standardised to a running sequence of numbers so extrapolations works on a linear scale.
    Args:
        y (list): list of values
        x (list): list of values
        n (int, optional): for how many times shall extrapolation be done. Defaults to 1. Larger values will start extrapolating on extrapolated values.

    Returns:
        list: extrapolated value(s) of y. The length of the list will be n.
    """
    # x and y must be arrays of same length
    # CHANGE THIS TO ASSERT
    if len(y) != len(x):
        print('array length mismatch')
        return None
    else:
        # format helper parameters to not modify lists outside the function
        xx = [*[i for i in x]]
        yy = [*[i for i in y]]
        return_list = [] # format list to be returned
        # loop n times -> return list of n length with n extrapolations
        # note: extrapolating on extrapolations if n>1
        while n >= 1:
            # format xx: it shall take a running sequence of numbers as its values
            xx = [i for i in range(len(x))]
            m = (yy[-1] - yy[-2]) / (xx[-1] - xx[-2])
            y_v = yy[-2] + m * ((xx[-1] + 1) - xx[-2])
            xx.append([xx[-1]+1])
            yy.append(y_v)
            return_list.append(y_v)
            n = n-1
        return return_list

# %%
# GET THE DATA
## non-lemmatised
df_speech_lengths_nl = pd.read_csv(f'{directory}/csv_analysis/speaker_speech_lengths_nonlemma.csv', sep=';', header=0, encoding='utf-8')
df_speeches_combined_length_nl = pd.read_csv(f'{directory}/csv_analysis/speeches_combined_plus_length_nonlemma.csv', sep=';', header=0, encoding='utf-8', dtype=str)
df_speaker_words_year_nl = pd.read_csv(f'{directory}/csv_analysis/speaker_words_comp_nonlemma.csv', sep=';', header=0, encoding='utf-8')
df_speaker_words_data_nl = pd.read_csv(f'{directory}/csv_analysis/speaker_words_comp_wide_nonlemma.csv', sep=';', header=0, encoding='utf-8')

# %% [markdown]
# *VISUALISATION*
#
# Plotting individual speeches. Line charts below show the development of minimum, maximum, mean, median and total lenghts of speeches. "Length" means the amount of words in speech. Total therefore means the total amount of words used by speaker in a year.
#
# Values are calculated per speaker, so each line represents a *speaker*.

# %%
# VISUALISATION
# the minimum length of of speeches HAS increased since the relase of chatgpt, although not by much
# plug in means and maxes, not much change there
x = df_speech_lengths_nl['year'].unique()

fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, sharex=True)

def plot_mins():
    avg_min = []
    for year in df_speech_lengths_nl['year'].unique():
        avg_min.append(df_speech_lengths_nl['len_min'].loc[df_speech_lengths_nl['year']==year].mean())

    for speaker in df_speech_lengths_nl['speaker_id'].unique():
        y_min = df_speech_lengths_nl['len_min'][df_speech_lengths_nl['speaker_id']==speaker].tolist()
        ax1.plot(x, y_min, color='grey', linestyle='dashed', linewidth=1)

    ax1.plot(x, avg_min, '.-', color='red')

    ax1.title.set_text('minimum amount of words in a speech')
    ax1.set_ylabel('words')

def plot_maxs():
    avg_max = []
    for year in df_speech_lengths_nl['year'].unique():
        avg_max.append(df_speech_lengths_nl['len_max'].loc[df_speech_lengths_nl['year']==year].mean())

    for speaker in df_speech_lengths_nl['speaker_id'].unique():
        y_max = df_speech_lengths_nl['len_max'][df_speech_lengths_nl['speaker_id']==speaker].tolist()
        ax2.plot(x, y_max, color='grey', linestyle='dashed', linewidth=1)

    ax2.plot(x, avg_max, '.-', color='red')

    ax2.title.set_text('maximum amount of words in a speech')
    ax2.set_ylabel('words')

def plot_means():
    avg_mean = []
    for year in df_speech_lengths_nl['year'].unique():
        avg_mean.append(df_speech_lengths_nl['len_mean'].loc[df_speech_lengths_nl['year']==year].mean())

    for speaker in df_speech_lengths_nl['speaker_id'].unique():
        y_mean = df_speech_lengths_nl['len_mean'][df_speech_lengths_nl['speaker_id']==speaker].tolist()
        ax3.plot(x, y_mean, color='grey', linestyle='dashed', linewidth=1)

    ax3.plot(x, avg_mean, '.-', color='red')

    ax3.title.set_text('mean amount of words in a speech')
    ax3.set_ylabel('words')
    ax3.set_xlabel('year')

def plot_medians():
    avg_median = []
    for year in df_speech_lengths_nl['year'].unique():
        avg_median.append(df_speech_lengths_nl['len_median'].loc[df_speech_lengths_nl['year']==year].median())

    for speaker in df_speech_lengths_nl['speaker_id'].unique():
        y_mean = df_speech_lengths_nl['len_median'][df_speech_lengths_nl['speaker_id']==speaker].tolist()
        ax4.plot(x, y_mean, color='grey', linestyle='dashed', linewidth=1)

    ax4.plot(x, avg_median, '.-', color='red')

    ax4.title.set_text('median amount of words in a speech')
    ax4.set_ylabel('words')
    ax4.set_xlabel('year')

def plot_total():
    avg_total = []
    for year in df_speech_lengths_nl['year'].unique():
        avg_total.append(df_speech_lengths_nl['words_total'].loc[df_speech_lengths_nl['year']==year].mean())

    for speaker in df_speech_lengths_nl['speaker_id'].unique():
        y_total = df_speech_lengths_nl['words_total'][df_speech_lengths_nl['speaker_id']==speaker].tolist()
        ax5.plot(x, y_total, color='grey', linestyle='dashed', linewidth=1)

    ax5.plot(x, avg_total, '.-', color='red')

    ax5.title.set_text('total amount of words in a speech')
    ax5.set_ylabel('words')
    ax5.set_xlabel('year')    
 
for ax in fig.get_axes():
    ax.label_outer()

fig.set_figheight(10)
fig.set_figwidth(10)
fig.set_constrained_layout(constrained=True)
plot_mins()
plot_maxs()
plot_means()
plot_medians()
plot_total()

plt.xticks(df_speech_lengths_nl['year'].unique())
plt.show()

# %% [markdown]
# *VISUALISATION*
#
# The bar chart below shows the total amount of words spoken per year.

# %%
x = df_speech_lengths_nl['year'].unique()

def plot_total_bar():
    y_total_bar = []
    for year in df_speech_lengths_nl['year'].unique():
        y_total_bar.append(df_speech_lengths_nl['words_total'].loc[df_speech_lengths_nl['year']==year].sum())

    plt.bar(x, height=y_total_bar)
    plt.title('total amount of words per year')
    plt.ylabel('words')
    plt.xlabel('year')  

plot_total_bar()
plt.xticks(df_speech_lengths_nl['year'].unique())
plt.show()

# %% [markdown]
# *VISUALISATION* NONLEMMATISED
#
# The pie charts below show the distribution of word classes used per year. These are created from the total speech content material from all speakers and are not divided by speaker.
#
# Nonlemmatised: the data is based on words that have not been lemmatised.

# %%
years = [re.search(r'\d+', i)[0] for i in df_speaker_words_data_nl.columns if re.search(r'word_n_\d+', i)]
# define set colors for each word class across multiple pie charts
colours = {}
cm = iter(colormaps['tab20c'].colors)
for c in df_speaker_words_data_nl['word_class'].unique():
    colours[c] = next(cm)
for year in years:
    plot_this = pd.DataFrame(columns=['year','class','n']).astype({'year':int,'class':str,'n':int})
    classes = df_speaker_words_data_nl['word_class'].loc[df_speaker_words_data_nl[f'word_n_{year}'].notna()].unique()
    l = []
    for c in classes:
        l.append(c)
        plot_this = pd.concat([plot_this, pd.DataFrame.from_dict({'year':[year],'class':[c],'n':[df_speaker_words_data_nl[f'word_norm_{year}'].loc[(df_speaker_words_data_nl[f'word_norm_{year}'].notna())&(df_speaker_words_data_nl['word_class']==c)].sum()]})])
    plt.pie(x=plot_this['n'], labels=l, autopct='%1.1f%%', colors=[colours[i] for i in [i for i in l]])
    plt.title(year)
    plt.show()

# %% [markdown]
# *VISUALISATION* NONLEMMATISED
#
# The line charts below show changes in the min-max normalised frequency of *some* words. Only words that have a SUM of frequency in the years 2024 and 2025 higher than the SUM of frequency in the years 2015-2023 are included. This is done to emphasise words the use of which has experienced a clear, critical increase in the past two years in the dataset.
#
# Nonlemmatised: the data is based on words that have not been lemmatised.

# %%
# VISUALISATION (NONLEMMATISED): 
# plot the words, that have an increased normalised frequency in 2024 and 2025 compared to 2015-2022 (let's try this first)
## get the words 
df_speaker_words_data_nl = pd.read_csv(f'{directory}/csv_analysis/speaker_words_comp_wide_nonlemma.csv', sep=';', header=0, encoding='utf-8')
## clean the word string one more time
df_speaker_words_data_nl['word'] = df_speaker_words_data_nl['word'].apply(clean_string)
## create a df which to plot
plot_this = pd.DataFrame(columns=['year','word','word_n','word_norm']).astype({'year':int, 'word':str, 'word_n':int, 'word_norm':float})

## populate the df
for year in [re.search(r'\d+', i)[0] for i in df_speaker_words_data_nl.columns if re.search(r'word_norm_\d+', i)]:
    # summarise word counts per each year in a temporary df
    word_counts = df_speaker_words_data_nl.groupby("word")[f'word_n_{year}'].sum().reset_index()
    word_counts = word_counts.rename(columns={f'word_n_{year}': 'word_n'})
    word_counts['year'] = int(year)
    word_counts['word_norm'] = None
    # normalise using min-maxing -> save in column 'word_norm'
    min_max = word_counts.groupby("year")["word_n"].agg(["min", "max"]).reset_index()
    word_counts = word_counts.merge(min_max, on='year', suffixes=('', '_stats'))
    word_counts['word_norm'] = ((word_counts['word_n']-word_counts['min'])/(word_counts['max']-word_counts['min']))
    word_counts = word_counts.drop(columns=["min", "max"])
    # concat the temp df to the final plottable df
    plot_this = pd.concat([plot_this, word_counts], axis=0, ignore_index=True)

## extract words which have increased in normalised frequency (higher word_norm in 2024, 2025 relative to 2015-2022)
### divide plot_this into 2 dataframes: one for years 2024-2025, and one for years before that
later_df = plot_this.loc[plot_this['year'].isin([2024, 2025])]
earlier_df = plot_this.loc[~plot_this['year'].isin([2024, 2025])]
later_df = later_df.loc[later_df['word'].isin(earlier_df['word'])]
later_df = later_df.merge(earlier_df[['word', 'word_norm']], on='word', suffixes=('', '_e'))
later_df = later_df[later_df['word_norm'] > later_df['word_norm_e']]
later_df = later_df.drop(columns=['word_norm_e'])
later_df = later_df.drop_duplicates()

plot_this = plot_this.loc[plot_this['word'].isin(later_df['word'])]

# %%
x = plot_this['year'].unique()
top_words = plot_this.groupby("word")["word_n"].sum().nlargest(100).index
df_top = plot_this[plot_this["word"].isin(top_words)]
for word in df_top['word'].unique():
    y = df_top['word_n'][df_top['word']==word]
    plt.plot(x, y, label=word, linestyle='-', color='grey')

plt.title(f'total amount of top 100 most used words per year')
plt.ylabel('word n per year')
plt.show()

# %%
x = plot_this['year'].unique()
for word in plot_this['word'].unique():
    y = plot_this['word_norm'].loc[plot_this['word']==word]
    plt.plot(x, y, label=word, linestyle='-', color='grey')

plt.xticks(plot_this['year'].unique())
plt.title(f'normalised frequency of word over years 2015-2025 - n words {len(plot_this['word'].unique())}')
plt.ylabel('normalised frequency, min-max norm, range 0.0-1.0')
plt.show()

# %%
# x-axis = years
x = plot_this['year'].unique()

# y-axis: word_norm
# limit only to top N words, where the difference between (2024,2025) > (years before) is the largest
later_df = plot_this.loc[plot_this['year'].isin([2024, 2025])]
earlier_df = plot_this.loc[~plot_this['year'].isin([2024, 2025])]

# order the words in later_df, descending based on the difference between word_norm values
earlier_word_norm_sums = earlier_df.groupby('word')['word_norm'].agg('sum').reset_index()
later_word_norm_sums = later_df.groupby('word')['word_norm'].agg('sum').reset_index()
compare_word_norm_sums = later_word_norm_sums.merge(earlier_word_norm_sums, how='left', on='word', suffixes=('_post','_pre'))

# keep the words where word_norm_post > word_norm_pre -> norm has increased 
compare_word_norm_sums = compare_word_norm_sums[compare_word_norm_sums['word_norm_post']>compare_word_norm_sums['word_norm_pre']]
compare_word_norm_sums.sort_values(by='word_norm_post', ascending=False, inplace=True)

# plot
for word in plot_this['word'][plot_this['word'].isin(compare_word_norm_sums['word'])]:
    y = plot_this['word_norm'].loc[plot_this['word']==word]
    plt.plot(x, y, label=word, linestyle='-', color='grey')

# show all years in the x-axis
plt.title(f'word frequencies (min-max normalisation) - NON-lemmatised words - n {len(plot_this['word'][plot_this['word'].isin(compare_word_norm_sums['word'])])}')
plt.ylabel('word frequency, min-max norm, range 0.0-1.0')
plt.xlabel('year') 
plt.xticks(plot_this['year'].unique())
plt.show()

# %%
# print each word and its sum of frequencies in 2024-2025 (word_norm_post) and its sum of frequencies in 2015-2023 (word_norm_pre)
# ordered by difference (word_norm_post-word_norm_pre) from largest difference to smallest, a total of 1004 words
compare_word_norm_sums['diff'] = (compare_word_norm_sums['word_norm_post']-compare_word_norm_sums['word_norm_pre'])
for i, d in compare_word_norm_sums.sort_values(by='diff', ascending=False).iterrows():
    print(compare_word_norm_sums.loc[i])
# Out:
# word                 naton
# word_norm_post    0.002203
# word_norm_pre     0.001671
# diff              0.000532
# Name: 7133, dtype: object
# word              asiantuntijakuulemisissa
# word_norm_post                    0.000911
# word_norm_pre                     0.000458
# diff                              0.000453
# Name: 643, dtype: object
# word              eutanasian
# word_norm_post      0.000544
# word_norm_pre       0.000203
# diff                0.000341
# Name: 1609, dtype: object
# word              palveluntuottajien
# word_norm_post              0.000451
# word_norm_pre               0.000114
# diff                        0.000337
# Name: 8286, dtype: object
# word              oulaskankaan
# word_norm_post        0.000379
# word_norm_pre         0.000051
# diff                  0.000327
# Name: 8094, dtype: object
# word              etelä-savossa
# word_norm_post         0.000317
# word_norm_pre          0.000011
# diff                   0.000306
# Name: 1523, dtype: object
# word              eutanasiaa
# word_norm_post      0.000495
# word_norm_pre       0.000203
# diff                0.000292
# Name: 1608, dtype: object
# word              rangaistavaa
# word_norm_post        0.000569
# word_norm_pre         0.000346
# diff                  0.000223
# Name: 9718, dtype: object
# word                 orpon
# word_norm_post    0.003121
# word_norm_pre     0.002903
# diff              0.000218
# Name: 7942, dtype: object
# word              pakkasen
# word_norm_post    0.000257
# word_norm_pre     0.000045
# diff              0.000213
# Name: 8188, dtype: object
# word              esittävän
# word_norm_post     0.000257
# word_norm_pre      0.000066
# diff               0.000191
# Name: 1461, dtype: object
# word              kulttuurista
# word_norm_post        0.001176
# word_norm_pre         0.000987
# diff                  0.000189
# Name: 4733, dtype: object
# word              tillväxt
# word_norm_post    0.000359
# word_norm_pre     0.000178
# diff               0.00018
# Name: 12081, dtype: object
# word              oikeusministeriössä
# word_norm_post               0.001119
# word_norm_pre                0.000939
# diff                          0.00018
# Name: 7601, dtype: object
# word                 virta
# word_norm_post    0.000309
# word_norm_pre      0.00013
# diff              0.000179
# Name: 14515, dtype: object
# word              rangaistavuuden
# word_norm_post           0.000349
# word_norm_pre            0.000174
# diff                     0.000175
# Name: 9720, dtype: object
# word                 petri
# word_norm_post    0.000171
# word_norm_pre          0.0
# diff              0.000171
# Name: 8671, dtype: object
# word              suurpetojen
# word_norm_post       0.000332
# word_norm_pre        0.000163
# diff                 0.000169
# Name: 11097, dtype: object
# word               ottawan
# word_norm_post    0.000371
# word_norm_pre     0.000202
# diff              0.000169
# Name: 8089, dtype: object
# word              sopeutukset
# word_norm_post       0.000386
# word_norm_pre         0.00022
# diff                 0.000166
# Name: 10738, dtype: object
# word              lukemattomia
# word_norm_post        0.000537
# word_norm_pre         0.000374
# diff                  0.000163
# Name: 5872, dtype: object
# word              sairailta
# word_norm_post     0.000304
# word_norm_pre      0.000143
# diff               0.000162
# Name: 10161, dtype: object
# word              ilmoituksia
# word_norm_post       0.000188
# word_norm_pre        0.000034
# diff                 0.000154
# Name: 2642, dtype: object
# word              kumppanuuksia
# word_norm_post          0.00027
# word_norm_pre           0.00012
# diff                    0.00015
# Name: 4769, dtype: object
# word              ukrainaan
# word_norm_post     0.000512
# word_norm_pre      0.000367
# diff               0.000145
# Name: 13257, dtype: object
# word              alamäkeen
# word_norm_post     0.000228
# word_norm_pre      0.000092
# diff               0.000136
# Name: 220, dtype: object
# word              miljonääreille
# word_norm_post          0.000161
# word_norm_pre           0.000028
# diff                    0.000133
# Name: 6675, dtype: object
# word              ympäristöluvan
# word_norm_post          0.000161
# word_norm_pre            0.00003
# diff                    0.000131
# Name: 15115, dtype: object
# word              häirintää
# word_norm_post      0.00022
# word_norm_pre      0.000092
# diff               0.000128
# Name: 2455, dtype: object
# word                 luvat
# word_norm_post     0.00026
# word_norm_pre     0.000135
# diff              0.000125
# Name: 5988, dtype: object
# word               luovien
# word_norm_post    0.000342
# word_norm_pre     0.000217
# diff              0.000125
# Name: 5953, dtype: object
# word              finanssipoliittiset
# word_norm_post               0.000124
# word_norm_pre                     0.0
# diff                         0.000124
# Name: 1628, dtype: object
# word              rangaistavaksi
# word_norm_post          0.000577
# word_norm_pre           0.000453
# diff                    0.000124
# Name: 9719, dtype: object
# word              myrkkyjä
# word_norm_post    0.000139
# word_norm_pre     0.000017
# diff              0.000121
# Name: 7031, dtype: object
# word              kirjanpitotasoinen
# word_norm_post              0.000129
# word_norm_pre                0.00001
# diff                        0.000118
# Name: 4149, dtype: object
# word              mitoituksen
# word_norm_post       0.000846
# word_norm_pre         0.00073
# diff                 0.000117
# Name: 6787, dtype: object
# word              vaalirahoituksen
# word_norm_post            0.000517
# word_norm_pre             0.000401
# diff                      0.000117
# Name: 13507, dtype: object
# word              aloittakaa
# word_norm_post      0.000124
# word_norm_pre       0.000009
# diff                0.000115
# Name: 317, dtype: object
# word                vatten
# word_norm_post    0.000171
# word_norm_pre      0.00006
# diff              0.000111
# Name: 14173, dtype: object
# word              valiokuntana
# word_norm_post        0.000178
# word_norm_pre         0.000069
# diff                  0.000109
# Name: 13767, dtype: object
# word                muisto
# word_norm_post    0.000106
# word_norm_pre          0.0
# diff              0.000106
# Name: 6887, dtype: object
# word              voimalaitoksia
# word_norm_post          0.000228
# word_norm_pre           0.000122
# diff                    0.000106
# Name: 14538, dtype: object
# word              kammottavan
# word_norm_post       0.000114
# word_norm_pre        0.000009
# diff                 0.000105
# Name: 3357, dtype: object
# word              puolustuskykyä
# word_norm_post          0.000317
# word_norm_pre           0.000212
# diff                    0.000105
# Name: 9226, dtype: object
# word              tulitauko
# word_norm_post     0.000121
# word_norm_pre      0.000021
# diff                 0.0001
# Name: 12547, dtype: object
# word              mineraaleja
# word_norm_post       0.000099
# word_norm_pre             0.0
# diff                 0.000099
# Name: 6706, dtype: object
# word                mereen
# word_norm_post    0.000099
# word_norm_pre          0.0
# diff              0.000099
# Name: 6516, dtype: object
# word              näyttääkin
# word_norm_post      0.000156
# word_norm_pre       0.000058
# diff                0.000098
# Name: 7471, dtype: object
# word              investointiavustuksen
# word_norm_post                 0.000131
# word_norm_pre                  0.000034
# diff                           0.000097
# Name: 2710, dtype: object
# word              irtisanominen
# word_norm_post         0.000097
# word_norm_pre               0.0
# diff                   0.000097
# Name: 2721, dtype: object
# word              kymäläinen
# word_norm_post      0.000765
# word_norm_pre        0.00067
# diff                0.000095
# Name: 4998, dtype: object
# word              suhdanne
# word_norm_post    0.000156
# word_norm_pre     0.000062
# diff              0.000094
# Name: 10870, dtype: object
# word              rikosoikeudellista
# word_norm_post              0.000186
# word_norm_pre               0.000094
# diff                        0.000091
# Name: 9932, dtype: object
# word              uhanalainen
# word_norm_post       0.000153
# word_norm_pre        0.000064
# diff                 0.000089
# Name: 13236, dtype: object
# word               typerää
# word_norm_post     0.00021
# word_norm_pre     0.000122
# diff              0.000088
# Name: 12872, dtype: object
# word              rajavartijoiden
# word_norm_post           0.000114
# word_norm_pre            0.000026
# diff                     0.000088
# Name: 9634, dtype: object
# word              kannusteet
# word_norm_post      0.000156
# word_norm_pre       0.000069
# diff                0.000087
# Name: 3422, dtype: object
# word              itäiseen
# word_norm_post    0.000121
# word_norm_pre     0.000034
# diff              0.000087
# Name: 2817, dtype: object
# word              vuorineuvokset
# word_norm_post          0.000121
# word_norm_pre           0.000034
# diff                    0.000087
# Name: 14592, dtype: object
# word              kannatti
# word_norm_post     0.00053
# word_norm_pre     0.000444
# diff              0.000086
# Name: 3408, dtype: object
# word              kotitalousvähennystä
# word_norm_post                0.000522
# word_norm_pre                 0.000437
# diff                          0.000085
# Name: 4594, dtype: object
# word              minkäännäköisiä
# word_norm_post           0.000181
# word_norm_pre            0.000096
# diff                     0.000084
# Name: 6752, dtype: object
# word              vakavasta
# word_norm_post      0.00021
# word_norm_pre      0.000127
# diff               0.000083
# Name: 13730, dtype: object
# word               näkyisi
# word_norm_post    0.000309
# word_norm_pre     0.000227
# diff              0.000083
# Name: 7432, dtype: object
# word              neuvotteluratkaisu
# word_norm_post              0.000099
# word_norm_pre               0.000017
# diff                        0.000082
# Name: 7184, dtype: object
# word                 pågår
# word_norm_post    0.000114
# word_norm_pre     0.000032
# diff              0.000082
# Name: 9543, dtype: object
# word                hullua
# word_norm_post    0.000082
# word_norm_pre          0.0
# diff              0.000082
# Name: 2235, dtype: object
# word              liikuntapalvelut
# word_norm_post            0.000082
# word_norm_pre                  0.0
# diff                      0.000082
# Name: 5669, dtype: object
# word              kultakaivos
# word_norm_post       0.000097
# word_norm_pre        0.000015
# diff                 0.000082
# Name: 4724, dtype: object
# word              katsellaan
# word_norm_post      0.000114
# word_norm_pre       0.000034
# diff                 0.00008
# Name: 3625, dtype: object
# word               ruuhkia
# word_norm_post    0.000114
# word_norm_pre     0.000034
# diff               0.00008
# Name: 10010, dtype: object
# word              operoida
# word_norm_post    0.000097
# word_norm_pre     0.000017
# diff              0.000079
# Name: 7836, dtype: object
# word              materiaalin
# word_norm_post       0.000097
# word_norm_pre        0.000017
# diff                 0.000079
# Name: 6398, dtype: object
# word              kulttuuristen
# word_norm_post         0.000097
# word_norm_pre          0.000017
# diff                   0.000079
# Name: 4734, dtype: object
# word              ansaitsevan
# word_norm_post       0.000097
# word_norm_pre        0.000017
# diff                 0.000079
# Name: 424, dtype: object
# word              keskituloista
# word_norm_post         0.000114
# word_norm_pre          0.000035
# diff                   0.000079
# Name: 3916, dtype: object
# word              utsjoella
# word_norm_post     0.000089
# word_norm_pre      0.000011
# diff               0.000079
# Name: 13413, dtype: object
# word                sdpssä
# word_norm_post    0.000299
# word_norm_pre     0.000222
# diff              0.000077
# Name: 10339, dtype: object
# word              keventäisimme
# word_norm_post         0.000106
# word_norm_pre          0.000031
# diff                   0.000075
# Name: 3996, dtype: object
# word                migrin
# word_norm_post    0.000074
# word_norm_pre          0.0
# diff              0.000074
# Name: 6647, dtype: object
# word              maarajaa
# word_norm_post    0.000121
# word_norm_pre     0.000049
# diff              0.000072
# Name: 6218, dtype: object
# word              yhdenmukaisia
# word_norm_post         0.000139
# word_norm_pre          0.000069
# diff                    0.00007
# Name: 14835, dtype: object
# word              köpkraften
# word_norm_post      0.000097
# word_norm_pre       0.000028
# diff                0.000069
# Name: 5253, dtype: object
# word              rikkaimmat
# word_norm_post      0.000153
# word_norm_pre       0.000086
# diff                0.000068
# Name: 9906, dtype: object
# word              ihmisoikeusloukkauksia
# word_norm_post                  0.000082
# word_norm_pre                   0.000015
# diff                            0.000067
# Name: 2560, dtype: object
# word                juomia
# word_norm_post    0.000082
# word_norm_pre     0.000015
# diff              0.000067
# Name: 3106, dtype: object
# word               uhataan
# word_norm_post    0.000099
# word_norm_pre     0.000034
# diff              0.000065
# Name: 13238, dtype: object
# word              fiskaalisesti
# word_norm_post         0.000082
# word_norm_pre          0.000017
# diff                   0.000065
# Name: 1640, dtype: object
# word              pettäneet
# word_norm_post     0.000082
# word_norm_pre      0.000017
# diff               0.000065
# Name: 8675, dtype: object
# word              röyhkeää
# word_norm_post    0.000082
# word_norm_pre     0.000017
# diff              0.000065
# Name: 10049, dtype: object
# word              rahoitusjärjestelmän
# word_norm_post                0.000082
# word_norm_pre                 0.000017
# diff                          0.000065
# Name: 9598, dtype: object
# word              riita-asioissa
# word_norm_post          0.000082
# word_norm_pre           0.000017
# diff                    0.000065
# Name: 9881, dtype: object
# word              toimipaikka
# word_norm_post       0.000064
# word_norm_pre             0.0
# diff                 0.000064
# Name: 12245, dtype: object
# word              lupaamanne
# word_norm_post      0.000064
# word_norm_pre            0.0
# diff                0.000064
# Name: 5960, dtype: object
# word              varjoonsa
# word_norm_post     0.000064
# word_norm_pre           0.0
# diff               0.000064
# Name: 14025, dtype: object
# word              vastauksiaarvoisa
# word_norm_post             0.000064
# word_norm_pre                   0.0
# diff                       0.000064
# Name: 14135, dtype: object
# word              hahmottua
# word_norm_post     0.000064
# word_norm_pre           0.0
# diff               0.000064
# Name: 1734, dtype: object
# word              tarkkailuluokalla
# word_norm_post             0.000064
# word_norm_pre                   0.0
# diff                       0.000064
# Name: 11555, dtype: object
# word                typerä
# word_norm_post    0.000064
# word_norm_pre          0.0
# diff              0.000064
# Name: 12871, dtype: object
# word              lahjojen
# word_norm_post    0.000064
# word_norm_pre          0.0
# diff              0.000064
# Name: 5326, dtype: object
# word              täyttäneiden
# word_norm_post        0.000064
# word_norm_pre              0.0
# diff                  0.000064
# Name: 13211, dtype: object
# word              häiritsemään
# word_norm_post        0.000064
# word_norm_pre              0.0
# diff                  0.000064
# Name: 2457, dtype: object
# word              rikosseuraamuslaitos
# word_norm_post                 0.00026
# word_norm_pre                 0.000196
# diff                          0.000064
# Name: 9933, dtype: object
# word              reserviin
# word_norm_post     0.000203
# word_norm_pre       0.00014
# diff               0.000063
# Name: 9854, dtype: object
# word              hallitusoppositio-rajan
# word_norm_post                   0.000082
# word_norm_pre                    0.000019
# diff                             0.000062
# Name: 1831, dtype: object
# word              rikosuhrimaksu
# word_norm_post          0.000097
# word_norm_pre           0.000034
# diff                    0.000062
# Name: 9935, dtype: object
# word              säästönä
# word_norm_post    0.000097
# word_norm_pre     0.000034
# diff              0.000062
# Name: 11285, dtype: object
# word              veronkevennysten
# word_norm_post            0.000097
# word_norm_pre             0.000036
# diff                       0.00006
# Name: 14256, dtype: object
# word              muistiot
# word_norm_post    0.000129
# word_norm_pre     0.000069
# diff               0.00006
# Name: 6885, dtype: object
# word                tuppaa
# word_norm_post    0.000245
# word_norm_pre     0.000185
# diff               0.00006
# Name: 12740, dtype: object
# word              oikeudenkäyntiin
# word_norm_post            0.000156
# word_norm_pre             0.000097
# diff                      0.000059
# Name: 7561, dtype: object
# word                regler
# word_norm_post    0.000188
# word_norm_pre     0.000129
# diff              0.000059
# Name: 9829, dtype: object
# word              seisonut
# word_norm_post    0.000082
# word_norm_pre     0.000024
# diff              0.000058
# Name: 10351, dtype: object
# word                jobben
# word_norm_post    0.000074
# word_norm_pre     0.000017
# diff              0.000057
# Name: 2900, dtype: object
# word              hakkuumäärät
# word_norm_post        0.000074
# word_norm_pre         0.000017
# diff                  0.000057
# Name: 1766, dtype: object
# word                ohjasi
# word_norm_post    0.000074
# word_norm_pre     0.000017
# diff              0.000057
# Name: 7506, dtype: object
# word              musiikkia
# word_norm_post     0.000121
# word_norm_pre      0.000064
# diff               0.000057
# Name: 6933, dtype: object
# word              annetuissa
# word_norm_post      0.000057
# word_norm_pre            0.0
# diff                0.000057
# Name: 416, dtype: object
# word              etulyöntiasema
# word_norm_post          0.000057
# word_norm_pre                0.0
# diff                    0.000057
# Name: 1557, dtype: object
# word              luovutuksesta
# word_norm_post         0.000057
# word_norm_pre               0.0
# diff                   0.000057
# Name: 5957, dtype: object
# word              työskenteleminen
# word_norm_post            0.000057
# word_norm_pre                  0.0
# diff                      0.000057
# Name: 13035, dtype: object
# word              jälkikäteenkin
# word_norm_post          0.000057
# word_norm_pre                0.0
# diff                    0.000057
# Name: 3142, dtype: object
# word              sanottavana
# word_norm_post       0.000057
# word_norm_pre             0.0
# diff                 0.000057
# Name: 10287, dtype: object
# word              vasemmistolaisinta
# word_norm_post              0.000057
# word_norm_pre                    0.0
# diff                        0.000057
# Name: 14073, dtype: object
# word              metsästykselle
# word_norm_post          0.000057
# word_norm_pre                0.0
# diff                    0.000057
# Name: 6568, dtype: object
# word              ehdokkaisiin
# word_norm_post        0.000057
# word_norm_pre              0.0
# diff                  0.000057
# Name: 1034, dtype: object
# word              tuomioistuimilta
# word_norm_post            0.000057
# word_norm_pre                  0.0
# diff                      0.000057
# Name: 12668, dtype: object
# word              sotilaille
# word_norm_post      0.000057
# word_norm_pre            0.0
# diff                0.000057
# Name: 10822, dtype: object
# word               selvisi
# word_norm_post     0.00076
# word_norm_pre     0.000704
# diff              0.000056
# Name: 10423, dtype: object
# word              rangaistavuus
# word_norm_post         0.000129
# word_norm_pre          0.000073
# diff                   0.000056
# Name: 9721, dtype: object
# word              verottaisimme
# word_norm_post         0.000099
# word_norm_pre          0.000043
# diff                   0.000056
# Name: 14282, dtype: object
# word              kohdistuen
# word_norm_post      0.000064
# word_norm_pre       0.000009
# diff                0.000056
# Name: 4236, dtype: object
# word              päihdeongelma
# word_norm_post         0.000139
# word_norm_pre          0.000084
# diff                   0.000055
# Name: 9367, dtype: object
# word               riistää
# word_norm_post    0.000089
# word_norm_pre     0.000034
# diff              0.000055
# Name: 9879, dtype: object
# word              veto-oikeutta
# word_norm_post         0.000089
# word_norm_pre          0.000034
# diff                   0.000055
# Name: 14325, dtype: object
# word              tillväxten
# word_norm_post      0.000161
# word_norm_pre       0.000108
# diff                0.000053
# Name: 12082, dtype: object
# word              uskomaton
# word_norm_post     0.000188
# word_norm_pre      0.000137
# diff               0.000051
# Name: 13367, dtype: object
# word                signal
# word_norm_post    0.000089
# word_norm_pre     0.000039
# diff               0.00005
# Name: 10523, dtype: object
# word              asiakirjojen
# word_norm_post        0.000131
# word_norm_pre         0.000081
# diff                   0.00005
# Name: 615, dtype: object
# word               syöneet
# word_norm_post    0.000129
# word_norm_pre     0.000079
# diff               0.00005
# Name: 11201, dtype: object
# word              subjektiiviset
# word_norm_post          0.000049
# word_norm_pre                0.0
# diff                    0.000049
# Name: 10867, dtype: object
# word              terveysongelmat
# word_norm_post           0.000049
# word_norm_pre                 0.0
# diff                     0.000049
# Name: 11919, dtype: object
# word               jamalla
# word_norm_post    0.000049
# word_norm_pre          0.0
# diff              0.000049
# Name: 2855, dtype: object
# word               koviten
# word_norm_post    0.000049
# word_norm_pre          0.0
# diff              0.000049
# Name: 4655, dtype: object
# word                   vem
# word_norm_post    0.000049
# word_norm_pre          0.0
# diff              0.000049
# Name: 14224, dtype: object
# word              tarvitsette
# word_norm_post       0.000049
# word_norm_pre             0.0
# diff                 0.000049
# Name: 11616, dtype: object
# word                 makua
# word_norm_post    0.000049
# word_norm_pre          0.0
# diff              0.000049
# Name: 6358, dtype: object
# word              suuntaamassa
# word_norm_post        0.000146
# word_norm_pre         0.000097
# diff                  0.000049
# Name: 11059, dtype: object
# word                sähköt
# word_norm_post    0.000129
# word_norm_pre     0.000079
# diff              0.000049
# Name: 11211, dtype: object
# word                  esim
# word_norm_post    0.000247
# word_norm_pre     0.000199
# diff              0.000049
# Name: 1411, dtype: object
# word              myönnätte
# word_norm_post     0.000099
# word_norm_pre      0.000051
# diff               0.000048
# Name: 7054, dtype: object
# word              ostamassa
# word_norm_post     0.000064
# word_norm_pre      0.000017
# diff               0.000048
# Name: 8035, dtype: object
# word              lupaatteko
# word_norm_post      0.000064
# word_norm_pre       0.000017
# diff                0.000048
# Name: 5962, dtype: object
# word              esiintyjät
# word_norm_post      0.000064
# word_norm_pre       0.000017
# diff                0.000048
# Name: 1407, dtype: object
# word              harveneminen
# word_norm_post        0.000064
# word_norm_pre         0.000017
# diff                  0.000047
# Name: 1936, dtype: object
# word              teknologisen
# word_norm_post        0.000064
# word_norm_pre         0.000017
# diff                  0.000047
# Name: 11864, dtype: object
# word              mallille
# word_norm_post    0.000064
# word_norm_pre     0.000017
# diff              0.000047
# Name: 6364, dtype: object
# word              pykälissä
# word_norm_post     0.000064
# word_norm_pre      0.000017
# diff               0.000047
# Name: 9292, dtype: object
# word              väliaikaisella
# word_norm_post          0.000064
# word_norm_pre           0.000017
# diff                    0.000047
# Name: 14735, dtype: object
# word              akuutteja
# word_norm_post     0.000064
# word_norm_pre      0.000017
# diff               0.000047
# Name: 205, dtype: object
# word              alaikäistä
# word_norm_post      0.000064
# word_norm_pre       0.000017
# diff                0.000047
# Name: 213, dtype: object
# word              nykyaikaista
# word_norm_post        0.000064
# word_norm_pre         0.000017
# diff                  0.000047
# Name: 7354, dtype: object
# word              käräjätuomari
# word_norm_post         0.000064
# word_norm_pre          0.000017
# diff                   0.000047
# Name: 5091, dtype: object
# word                   fem
# word_norm_post    0.000148
# word_norm_pre     0.000102
# diff              0.000047
# Name: 1623, dtype: object
# word              johdatte
# word_norm_post    0.000114
# word_norm_pre     0.000068
# diff              0.000046
# Name: 2905, dtype: object
# word              säästötoimia
# word_norm_post        0.000196
# word_norm_pre          0.00015
# diff                  0.000045
# Name: 11298, dtype: object
# word              tienaava
# word_norm_post    0.000161
# word_norm_pre     0.000116
# diff              0.000045
# Name: 11965, dtype: object
# word              erityisessä
# word_norm_post       0.000124
# word_norm_pre        0.000079
# diff                 0.000045
# Name: 1384, dtype: object
# word               murusia
# word_norm_post    0.000097
# word_norm_pre     0.000052
# diff              0.000045
# Name: 6929, dtype: object
# word              rikosoikeudellinen
# word_norm_post              0.000097
# word_norm_pre               0.000053
# diff                        0.000043
# Name: 9931, dtype: object
# word              puolustuskyky
# word_norm_post         0.000074
# word_norm_pre          0.000032
# diff                   0.000042
# Name: 9225, dtype: object
# word              kannanhoidolliselle
# word_norm_post               0.000057
# word_norm_pre                0.000015
# diff                         0.000042
# Name: 3372, dtype: object
# word              ulkopuolellakin
# word_norm_post           0.000089
# word_norm_pre            0.000047
# diff                     0.000042
# Name: 13290, dtype: object
# word                 sulaa
# word_norm_post    0.000114
# word_norm_pre     0.000072
# diff              0.000041
# Name: 10911, dtype: object
# word              vaalirahoitukseen
# word_norm_post             0.000049
# word_norm_pre              0.000009
# diff                       0.000041
# Name: 13506, dtype: object
# word                saanti
# word_norm_post    0.000641
# word_norm_pre     0.000601
# diff               0.00004
# Name: 10079, dtype: object
# word              loukkaavan
# word_norm_post      0.000057
# word_norm_pre       0.000017
# diff                 0.00004
# Name: 5858, dtype: object
# word              förvaltningen
# word_norm_post         0.000057
# word_norm_pre          0.000017
# diff                    0.00004
# Name: 1683, dtype: object
# word              kohdistamalla
# word_norm_post         0.000057
# word_norm_pre          0.000017
# diff                    0.00004
# Name: 4229, dtype: object
# word              suvereniteetin
# word_norm_post          0.000057
# word_norm_pre           0.000017
# diff                     0.00004
# Name: 11105, dtype: object
# word              esityksessäkin
# word_norm_post          0.000057
# word_norm_pre           0.000017
# diff                     0.00004
# Name: 1472, dtype: object
# word              sektorillanne
# word_norm_post         0.000057
# word_norm_pre          0.000017
# diff                    0.00004
# Name: 10369, dtype: object
# word              perustuslakiasiantuntijoitten
# word_norm_post                         0.000057
# word_norm_pre                          0.000017
# diff                                    0.00004
# Name: 8638, dtype: object
# word              tekevistä
# word_norm_post     0.000057
# word_norm_pre      0.000017
# diff                0.00004
# Name: 11834, dtype: object
# word              länsi-uusimaa
# word_norm_post         0.000057
# word_norm_pre          0.000017
# diff                    0.00004
# Name: 6087, dtype: object
# word              kannustimen
# word_norm_post       0.000057
# word_norm_pre        0.000017
# diff                  0.00004
# Name: 3424, dtype: object
# word              itäisestä
# word_norm_post     0.000057
# word_norm_pre      0.000017
# diff                0.00004
# Name: 2818, dtype: object
# word              valmistelemiseksi
# word_norm_post             0.000049
# word_norm_pre              0.000011
# diff                       0.000039
# Name: 13810, dtype: object
# word              päämiehensä
# word_norm_post       0.000064
# word_norm_pre        0.000026
# diff                 0.000039
# Name: 9435, dtype: object
# word              kännykät
# word_norm_post    0.000082
# word_norm_pre     0.000043
# diff              0.000039
# Name: 5080, dtype: object
# word              pihoissa
# word_norm_post    0.000097
# word_norm_pre     0.000058
# diff              0.000039
# Name: 8759, dtype: object
# word              teillämme
# word_norm_post     0.000064
# word_norm_pre      0.000026
# diff               0.000038
# Name: 11803, dtype: object
# word              leikkaantuu
# word_norm_post       0.000124
# word_norm_pre        0.000085
# diff                 0.000038
# Name: 5582, dtype: object
# word              yhteiselle
# word_norm_post      0.000089
# word_norm_pre       0.000051
# diff                0.000038
# Name: 14874, dtype: object
# word              poliittisiin
# word_norm_post        0.000089
# word_norm_pre         0.000051
# diff                  0.000038
# Name: 8975, dtype: object
# word              alkuperämerkintöjen
# word_norm_post               0.000074
# word_norm_pre                0.000037
# diff                         0.000038
# Name: 283, dtype: object
# word              työsuojelu
# word_norm_post      0.000064
# word_norm_pre       0.000028
# diff                0.000037
# Name: 13045, dtype: object
# word              rintamilla
# word_norm_post      0.000064
# word_norm_pre       0.000028
# diff                0.000037
# Name: 9948, dtype: object
# word              semmoisissa
# word_norm_post       0.000057
# word_norm_pre        0.000021
# diff                 0.000036
# Name: 10462, dtype: object
# word              toimistossa
# word_norm_post       0.000057
# word_norm_pre        0.000021
# diff                 0.000036
# Name: 12251, dtype: object
# word              politiikkaansa
# word_norm_post          0.000213
# word_norm_pre           0.000178
# diff                    0.000035
# Name: 8989, dtype: object
# word              esittelypuheessaan
# word_norm_post              0.000064
# word_norm_pre                0.00003
# diff                        0.000034
# Name: 1449, dtype: object
# word              sinänsähän
# word_norm_post      0.000124
# word_norm_pre        0.00009
# diff                0.000034
# Name: 10616, dtype: object
# word              elpymisen
# word_norm_post     0.000129
# word_norm_pre      0.000096
# diff               0.000033
# Name: 1131, dtype: object
# word              houkuttelee
# word_norm_post       0.000082
# word_norm_pre        0.000049
# diff                 0.000033
# Name: 2221, dtype: object
# word                lehtiä
# word_norm_post    0.000161
# word_norm_pre     0.000128
# diff              0.000033
# Name: 5564, dtype: object
# word              turkistarhaus
# word_norm_post         0.000049
# word_norm_pre          0.000017
# diff                   0.000033
# Name: 12752, dtype: object
# word                 tehon
# word_norm_post    0.000049
# word_norm_pre     0.000017
# diff              0.000033
# Name: 11759, dtype: object
# word               kuolema
# word_norm_post    0.000228
# word_norm_pre     0.000195
# diff              0.000033
# Name: 4830, dtype: object
# word              ihmetellään
# word_norm_post        0.00027
# word_norm_pre        0.000237
# diff                 0.000032
# Name: 2520, dtype: object
# word              uskottavuutensa
# word_norm_post           0.000049
# word_norm_pre            0.000017
# diff                     0.000032
# Name: 13403, dtype: object
# word              tytöillä
# word_norm_post    0.000049
# word_norm_pre     0.000017
# diff              0.000032
# Name: 12876, dtype: object
# word              eräänlaisessa
# word_norm_post         0.000049
# word_norm_pre          0.000017
# diff                   0.000032
# Name: 1404, dtype: object
# word              aurinkovoimaa
# word_norm_post         0.000049
# word_norm_pre          0.000017
# diff                   0.000032
# Name: 711, dtype: object
# word              kustannusnousun
# word_norm_post           0.000049
# word_norm_pre            0.000017
# diff                     0.000032
# Name: 4858, dtype: object
# word              yrityskohtaisesti
# word_norm_post             0.000049
# word_norm_pre              0.000017
# diff                       0.000032
# Name: 15167, dtype: object
# word              tavallisessa
# word_norm_post        0.000049
# word_norm_pre         0.000017
# diff                  0.000032
# Name: 11689, dtype: object
# word              laskennallisen
# word_norm_post          0.000049
# word_norm_pre           0.000017
# diff                    0.000032
# Name: 5509, dtype: object
# word              välttämättömyyteen
# word_norm_post              0.000049
# word_norm_pre               0.000017
# diff                        0.000032
# Name: 14777, dtype: object
# word              päreiksi
# word_norm_post    0.000049
# word_norm_pre     0.000017
# diff              0.000032
# Name: 9407, dtype: object
# word               nuorina
# word_norm_post    0.000049
# word_norm_pre     0.000017
# diff              0.000032
# Name: 7341, dtype: object
# word              oikeudenkäyntejä
# word_norm_post            0.000049
# word_norm_pre             0.000017
# diff                      0.000032
# Name: 7559, dtype: object
# word              naisyrittäjät
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 7128, dtype: object
# word                naurun
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 7143, dtype: object
# word              naapureita
# word_norm_post      0.000032
# word_norm_pre            0.0
# diff                0.000032
# Name: 7112, dtype: object
# word              sovittuihin
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 10837, dtype: object
# word              arveluttavana
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 481, dtype: object
# word              rikoksentekijää
# word_norm_post           0.000032
# word_norm_pre                 0.0
# diff                     0.000032
# Name: 9917, dtype: object
# word              hallitusohjelmakirjaus
# word_norm_post                  0.000032
# word_norm_pre                        0.0
# diff                            0.000032
# Name: 1825, dtype: object
# word              kannattavuustilanne
# word_norm_post               0.000032
# word_norm_pre                     0.0
# diff                         0.000032
# Name: 3405, dtype: object
# word              työllisyyskeskusteluun
# word_norm_post                  0.000032
# word_norm_pre                        0.0
# diff                            0.000032
# Name: 12948, dtype: object
# word              kysytäänpä
# word_norm_post      0.000032
# word_norm_pre            0.0
# diff                0.000032
# Name: 5065, dtype: object
# word              vasemmaltame
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 14070, dtype: object
# word              karsimisia
# word_norm_post      0.000032
# word_norm_pre            0.0
# diff                0.000032
# Name: 3545, dtype: object
# word              energiaomavaraisuutta
# word_norm_post                 0.000032
# word_norm_pre                       0.0
# diff                           0.000032
# Name: 1227, dtype: object
# word              suosituksessa
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 10998, dtype: object
# word              onnettomuuksista
# word_norm_post            0.000032
# word_norm_pre                  0.0
# diff                      0.000032
# Name: 7818, dtype: object
# word              väärillä
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 14796, dtype: object
# word              oppitunneilla
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 7915, dtype: object
# word              oppitunnilla
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 7916, dtype: object
# word              oikeudentuntoon
# word_norm_post           0.000032
# word_norm_pre                 0.0
# diff                     0.000032
# Name: 7576, dtype: object
# word              vastaanotossa
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 14088, dtype: object
# word              paperityöstä
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 8336, dtype: object
# word              kannanotollaan
# word_norm_post          0.000032
# word_norm_pre                0.0
# diff                    0.000032
# Name: 3373, dtype: object
# word              sodankäynnin
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 10718, dtype: object
# word              tutustuisitte
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 12858, dtype: object
# word              mielivaltaisesti
# word_norm_post            0.000032
# word_norm_pre                  0.0
# diff                      0.000032
# Name: 6618, dtype: object
# word                 aidan
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 24, dtype: object
# word              mustasalkkuiset
# word_norm_post           0.000032
# word_norm_pre                 0.0
# diff                     0.000032
# Name: 6936, dtype: object
# word                vasara
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 14066, dtype: object
# word              tutkimustoiminnan
# word_norm_post             0.000032
# word_norm_pre                   0.0
# diff                       0.000032
# Name: 12846, dtype: object
# word              tutkimuksien
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 12839, dtype: object
# word              turvatun
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 12818, dtype: object
# word              vaatimukseksi
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 13534, dtype: object
# word              esiteltävässä
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 1424, dtype: object
# word              minuutteja
# word_norm_post      0.000032
# word_norm_pre            0.0
# diff                0.000032
# Name: 6765, dtype: object
# word              minuuttini
# word_norm_post      0.000032
# word_norm_pre            0.0
# diff                0.000032
# Name: 6768, dtype: object
# word              muodostaisi
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 6913, dtype: object
# word              pienimmätkin
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 8731, dtype: object
# word               perutte
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 8657, dtype: object
# word              irtaantumista
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 2719, dtype: object
# word              irtisanoutuminen
# word_norm_post            0.000032
# word_norm_pre                  0.0
# diff                      0.000032
# Name: 2725, dtype: object
# word              johtuisikohan
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 2935, dtype: object
# word              syksyisin
# word_norm_post     0.000032
# word_norm_pre           0.0
# diff               0.000032
# Name: 11120, dtype: object
# word                svarta
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 11106, dtype: object
# word              sinivalkoinen
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 10608, dtype: object
# word              hankintaprosessi
# word_norm_post            0.000032
# word_norm_pre                  0.0
# diff                      0.000032
# Name: 1891, dtype: object
# word              kaveriksi
# word_norm_post     0.000032
# word_norm_pre           0.0
# diff               0.000032
# Name: 3712, dtype: object
# word              kauppaketju
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 3696, dtype: object
# word              kaupanteon
# word_norm_post      0.000032
# word_norm_pre            0.0
# diff                0.000032
# Name: 3688, dtype: object
# word              kasvupotentiaali
# word_norm_post            0.000032
# word_norm_pre                  0.0
# diff                      0.000032
# Name: 3604, dtype: object
# word                saahan
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 10056, dtype: object
# word              pakkopaketin
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 8192, dtype: object
# word              harjoittelee
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 1912, dtype: object
# word              viipymät
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 14435, dtype: object
# word                 sitoi
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 10667, dtype: object
# word                 rejäl
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 9845, dtype: object
# word              elinkeinoelämäkin
# word_norm_post             0.000032
# word_norm_pre                   0.0
# diff                       0.000032
# Name: 1108, dtype: object
# word              esitelläkseni
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 1421, dtype: object
# word              ministerineuvosto
# word_norm_post             0.000032
# word_norm_pre                   0.0
# diff                       0.000032
# Name: 6722, dtype: object
# word              tärkeäämutta
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 13172, dtype: object
# word              passivoiva
# word_norm_post      0.000032
# word_norm_pre            0.0
# diff                0.000032
# Name: 8421, dtype: object
# word              oululaisena
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 8096, dtype: object
# word              oppositiorajan
# word_norm_post          0.000032
# word_norm_pre                0.0
# diff                    0.000032
# Name: 7930, dtype: object
# word              sisältämä
# word_norm_post     0.000032
# word_norm_pre           0.0
# diff               0.000032
# Name: 10646, dtype: object
# word              ongelmiakin
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 7805, dtype: object
# word              täytettyä
# word_norm_post     0.000032
# word_norm_pre           0.0
# diff               0.000032
# Name: 13206, dtype: object
# word                 perun
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 8539, dtype: object
# word              ulkopuoliselta
# word_norm_post          0.000032
# word_norm_pre                0.0
# diff                    0.000032
# Name: 13293, dtype: object
# word              haukkuneet
# word_norm_post      0.000032
# word_norm_pre            0.0
# diff                0.000032
# Name: 1939, dtype: object
# word              tavoitellaarvoisa
# word_norm_post             0.000032
# word_norm_pre                   0.0
# diff                       0.000032
# Name: 11704, dtype: object
# word              lautakuntiin
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 5558, dtype: object
# word              toimeentulotukiriippuvuutta
# word_norm_post                       0.000032
# word_norm_pre                             0.0
# diff                                 0.000032
# Name: 12163, dtype: object
# word              ruokaketjun
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 9994, dtype: object
# word              loppuaikana
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 5831, dtype: object
# word              lanseeranneet
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 5460, dtype: object
# word              lautakuntaan
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 5557, dtype: object
# word              purkanut
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 9252, dtype: object
# word                uransa
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 13332, dtype: object
# word              budjettiraamin
# word_norm_post          0.000032
# word_norm_pre                0.0
# diff                    0.000032
# Name: 818, dtype: object
# word              verratkaa
# word_norm_post     0.000032
# word_norm_pre           0.0
# diff               0.000032
# Name: 14303, dtype: object
# word              vientiala
# word_norm_post     0.000032
# word_norm_pre           0.0
# diff               0.000032
# Name: 14357, dtype: object
# word              rakennuslautakuntaan
# word_norm_post                0.000032
# word_norm_pre                      0.0
# diff                          0.000032
# Name: 9681, dtype: object
# word              voimasuhteet
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 14543, dtype: object
# word              satsaisimme
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 10322, dtype: object
# word              puolustelitte
# word_norm_post         0.000032
# word_norm_pre               0.0
# diff                   0.000032
# Name: 9217, dtype: object
# word              alkupuheenvuorossanne
# word_norm_post                 0.000032
# word_norm_pre                       0.0
# diff                           0.000032
# Name: 284, dtype: object
# word              häthätää
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 2486, dtype: object
# word                 pilke
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 8779, dtype: object
# word              vanhimmasta
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 13942, dtype: object
# word              vaalirahailmoitus
# word_norm_post             0.000032
# word_norm_pre                   0.0
# diff                       0.000032
# Name: 13505, dtype: object
# word              yhdysvalloilta
# word_norm_post          0.000032
# word_norm_pre                0.0
# diff                    0.000032
# Name: 14861, dtype: object
# word              ilmavoimiin
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 2620, dtype: object
# word                irania
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 2717, dtype: object
# word              länsimailta
# word_norm_post       0.000032
# word_norm_pre             0.0
# diff                 0.000032
# Name: 6088, dtype: object
# word              löytääksemme
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 6146, dtype: object
# word              tunnustaneet
# word_norm_post        0.000032
# word_norm_pre              0.0
# diff                  0.000032
# Name: 12626, dtype: object
# word              kohtuullistaminen
# word_norm_post             0.000032
# word_norm_pre                   0.0
# diff                       0.000032
# Name: 4290, dtype: object
# word              fasistien
# word_norm_post     0.000032
# word_norm_pre           0.0
# diff               0.000032
# Name: 1621, dtype: object
# word                sänder
# word_norm_post    0.000032
# word_norm_pre          0.0
# diff              0.000032
# Name: 11228, dtype: object
# word              hallintoalojen
# word_norm_post          0.000032
# word_norm_pre                0.0
# diff                    0.000032
# ...
# word_norm_post          0.000025
# word_norm_pre           0.000017
# diff                    0.000008
# Name: 15101, dtype: object
# word                  valo
# word_norm_post    0.000025
# word_norm_pre     0.000017
# diff              0.000008
# Name: 13832, dtype: object
# word              hyväksymällä
# word_norm_post        0.000025
# word_norm_pre         0.000017
# diff                  0.000008
# Name: 2390, dtype: object
# word              varrelle
# word_norm_post    0.000025
# word_norm_pre     0.000017
# diff              0.000008
# Name: 14052, dtype: object
# word              forssassa
# word_norm_post     0.000025
# word_norm_pre      0.000017
# diff               0.000008
# Name: 1648, dtype: object
# word              fundamentteja
# word_norm_post         0.000025
# word_norm_pre          0.000017
# diff                   0.000008
# Name: 1664, dtype: object
# word              henkilöstömitoitukseen
# word_norm_post                  0.000025
# word_norm_pre                   0.000017
# diff                            0.000008
# Name: 2075, dtype: object
# word              havahduttu
# word_norm_post      0.000025
# word_norm_pre       0.000017
# diff                0.000008
# Name: 1942, dtype: object
# word                harras
# word_norm_post    0.000025
# word_norm_pre     0.000017
# diff              0.000008
# Name: 1928, dtype: object
# word              valintamme
# word_norm_post      0.000025
# word_norm_pre       0.000017
# diff                0.000008
# Name: 13754, dtype: object
# word              vastuullanne
# word_norm_post        0.000025
# word_norm_pre         0.000017
# diff                  0.000008
# Name: 14156, dtype: object
# word              ratkaistavissa
# word_norm_post          0.000025
# word_norm_pre           0.000017
# diff                    0.000008
# Name: 9776, dtype: object
# word              läheisyydessä
# word_norm_post         0.000178
# word_norm_pre          0.000171
# diff                   0.000008
# Name: 6028, dtype: object
# word              wallinheimo
# word_norm_post        0.00026
# word_norm_pre        0.000253
# diff                 0.000007
# Name: 14819, dtype: object
# word              oppiaine
# word_norm_post    0.000025
# word_norm_pre     0.000017
# diff              0.000007
# Name: 7893, dtype: object
# word              maailmankatsomukset
# word_norm_post               0.000025
# word_norm_pre                0.000017
# diff                         0.000007
# Name: 6173, dtype: object
# word              uskontokunnista
# word_norm_post           0.000025
# word_norm_pre            0.000017
# diff                     0.000007
# Name: 13387, dtype: object
# word              laatiminen
# word_norm_post      0.000049
# word_norm_pre       0.000042
# diff                0.000007
# Name: 5314, dtype: object
# word              keissejä
# word_norm_post    0.000049
# word_norm_pre     0.000043
# diff              0.000007
# Name: 3784, dtype: object
# word              yhdysvalloista
# word_norm_post          0.000082
# word_norm_pre           0.000075
# diff                    0.000007
# Name: 14863, dtype: object
# word              uskonnot
# word_norm_post    0.000049
# word_norm_pre     0.000043
# diff              0.000006
# Name: 13381, dtype: object
# word              muutoshan
# word_norm_post     0.000049
# word_norm_pre      0.000043
# diff               0.000006
# Name: 6995, dtype: object
# word              älykkäitä
# word_norm_post     0.000032
# word_norm_pre      0.000026
# diff               0.000006
# Name: 15193, dtype: object
# word              jalostamiseen
# word_norm_post         0.000032
# word_norm_pre          0.000026
# diff                   0.000006
# Name: 2853, dtype: object
# word              vanhentunutta
# word_norm_post         0.000032
# word_norm_pre          0.000026
# diff                   0.000006
# Name: 13940, dtype: object
# word              todellisuudessahan
# word_norm_post              0.000032
# word_norm_pre               0.000026
# diff                        0.000006
# Name: 12122, dtype: object
# word               hylätty
# word_norm_post    0.000032
# word_norm_pre     0.000026
# diff              0.000006
# Name: 2348, dtype: object
# word              eläkemaksut
# word_norm_post       0.000032
# word_norm_pre        0.000026
# diff                 0.000006
# Name: 1156, dtype: object
# word               siksipä
# word_norm_post    0.000755
# word_norm_pre     0.000749
# diff              0.000006
# Name: 10581, dtype: object
# word              vaihteeksi
# word_norm_post      0.000032
# word_norm_pre       0.000026
# diff                0.000006
# Name: 13598, dtype: object
# word              työperäiseen
# word_norm_post        0.000074
# word_norm_pre         0.000068
# diff                  0.000006
# Name: 13025, dtype: object
# word              selvittämistä
# word_norm_post         0.000153
# word_norm_pre          0.000148
# diff                   0.000006
# Name: 10432, dtype: object
# word              lepäävät
# word_norm_post    0.000025
# word_norm_pre     0.000019
# diff              0.000006
# Name: 5613, dtype: object
# word              suuntaisia
# word_norm_post      0.000025
# word_norm_pre       0.000019
# diff                0.000006
# Name: 11061, dtype: object
# word              hallituspuolueetkin
# word_norm_post               0.000025
# word_norm_pre                0.000019
# diff                         0.000006
# Name: 1838, dtype: object
# word              lisättävää
# word_norm_post      0.000057
# word_norm_pre       0.000051
# diff                0.000006
# Name: 5763, dtype: object
# word              tietojenvaihtoa
# word_norm_post           0.000057
# word_norm_pre            0.000051
# diff                     0.000006
# Name: 11991, dtype: object
# word                   aho
# word_norm_post    0.000057
# word_norm_pre     0.000052
# diff              0.000005
# Name: 21, dtype: object
# word              pelkäämättä
# word_norm_post       0.000057
# word_norm_pre        0.000052
# diff                 0.000005
# Name: 8465, dtype: object
# word              pankeille
# word_norm_post     0.000082
# word_norm_pre      0.000077
# diff               0.000005
# Name: 8294, dtype: object
# word                 hämta
# word_norm_post    0.000064
# word_norm_pre     0.000059
# diff              0.000005
# Name: 2473, dtype: object
# word              toimintaympäristömme
# word_norm_post                0.000097
# word_norm_pre                 0.000092
# diff                          0.000005
# Name: 12239, dtype: object
# word              lausumasta
# word_norm_post      0.000049
# word_norm_pre       0.000045
# diff                0.000005
# Name: 5542, dtype: object
# word              hyvinvointivelkaa
# word_norm_post             0.000049
# word_norm_pre              0.000045
# diff                       0.000005
# Name: 2368, dtype: object
# word              digitaalisuudesta
# word_norm_post             0.000032
# word_norm_pre              0.000027
# diff                       0.000005
# Name: 874, dtype: object
# word              laatijat
# word_norm_post    0.000049
# word_norm_pre     0.000045
# diff              0.000005
# Name: 5312, dtype: object
# word              veronkevennykseen
# word_norm_post             0.000032
# word_norm_pre              0.000028
# diff                       0.000005
# Name: 14251, dtype: object
# word              tiedonkulkua
# word_norm_post        0.000032
# word_norm_pre         0.000028
# diff                  0.000005
# Name: 11947, dtype: object
# word              isommalta
# word_norm_post     0.000032
# word_norm_pre      0.000028
# diff               0.000005
# Name: 2743, dtype: object
# word              rakenteeltaan
# word_norm_post         0.000032
# word_norm_pre          0.000028
# diff                   0.000005
# Name: 9710, dtype: object
# word              metsäomaisuus
# word_norm_post         0.000032
# word_norm_pre          0.000028
# diff                   0.000005
# Name: 6565, dtype: object
# word              hallinnot
# word_norm_post     0.000032
# word_norm_pre      0.000028
# diff               0.000005
# Name: 1779, dtype: object
# word              lupaprosessissa
# word_norm_post           0.000032
# word_norm_pre            0.000028
# diff                     0.000005
# Name: 5967, dtype: object
# word              käytännönläheistä
# word_norm_post             0.000032
# word_norm_pre              0.000028
# diff                       0.000005
# Name: 5225, dtype: object
# word              tarjoutuu
# word_norm_post     0.000032
# word_norm_pre      0.000028
# diff               0.000005
# Name: 11521, dtype: object
# word              kansalaistoimintaan
# word_norm_post               0.000032
# word_norm_pre                0.000028
# diff                         0.000005
# Name: 3469, dtype: object
# word              työntekijään
# word_norm_post        0.000032
# word_norm_pre         0.000028
# diff                  0.000005
# Name: 13001, dtype: object
# word              pohdinnat
# word_norm_post     0.000032
# word_norm_pre      0.000028
# diff               0.000005
# Name: 8853, dtype: object
# word              säätäneet
# word_norm_post     0.000156
# word_norm_pre      0.000151
# diff               0.000005
# Name: 11309, dtype: object
# word                 merta
# word_norm_post    0.000032
# word_norm_pre     0.000028
# diff              0.000004
# Name: 6549, dtype: object
# word                minkäs
# word_norm_post    0.000032
# word_norm_pre     0.000028
# diff              0.000004
# Name: 6747, dtype: object
# word              tekemisistään
# word_norm_post         0.000032
# word_norm_pre          0.000028
# diff                   0.000004
# Name: 11816, dtype: object
# word              vastaavilta
# word_norm_post       0.000032
# word_norm_pre        0.000028
# diff                 0.000004
# Name: 14103, dtype: object
# word              valvontatehtäviä
# word_norm_post            0.000032
# word_norm_pre             0.000028
# diff                      0.000004
# Name: 13913, dtype: object
# word              vakuuteltu
# word_norm_post      0.000032
# word_norm_pre       0.000028
# diff                0.000004
# Name: 13740, dtype: object
# word              keskuudestamme
# word_norm_post          0.000032
# word_norm_pre           0.000028
# diff                    0.000004
# Name: 3953, dtype: object
# word              poronhoito
# word_norm_post      0.000032
# word_norm_pre       0.000028
# diff                0.000004
# Name: 9001, dtype: object
# word              sopivana
# word_norm_post    0.000032
# word_norm_pre     0.000028
# diff              0.000004
# Name: 10772, dtype: object
# word              ajankohdan
# word_norm_post      0.000032
# word_norm_pre       0.000028
# diff                0.000004
# Name: 141, dtype: object
# word               tuorein
# word_norm_post    0.000032
# word_norm_pre     0.000028
# diff              0.000004
# Name: 12687, dtype: object
# word               ajautui
# word_norm_post    0.000032
# word_norm_pre     0.000028
# diff              0.000004
# Name: 183, dtype: object
# word              pelleily
# word_norm_post    0.000025
# word_norm_pre     0.000021
# diff              0.000004
# Name: 8468, dtype: object
# word              yliopistollisen
# word_norm_post           0.000025
# word_norm_pre            0.000021
# diff                     0.000004
# Name: 15053, dtype: object
# word              kehittämisajatuksia
# word_norm_post               0.000025
# word_norm_pre                0.000021
# diff                         0.000004
# Name: 3728, dtype: object
# word              täyttäneet
# word_norm_post      0.000121
# word_norm_pre       0.000117
# diff                0.000004
# Name: 13210, dtype: object
# word              kehityssuuntaa
# word_norm_post          0.000025
# word_norm_pre           0.000021
# diff                    0.000004
# Name: 3751, dtype: object
# word              täyttäneille
# word_norm_post        0.000064
# word_norm_pre         0.000061
# diff                  0.000004
# Name: 13212, dtype: object
# word                betyda
# word_norm_post    0.000089
# word_norm_pre     0.000085
# diff              0.000004
# Name: 786, dtype: object
# word              ihmettelemmekin
# word_norm_post           0.000025
# word_norm_pre            0.000021
# diff                     0.000004
# Name: 2525, dtype: object
# word               lujasti
# word_norm_post    0.000089
# word_norm_pre     0.000086
# diff              0.000003
# Name: 5867, dtype: object
# word              suhdannepolitiikkaa
# word_norm_post               0.000064
# word_norm_pre                0.000062
# diff                         0.000003
# Name: 10871, dtype: object
# word              ministerinne
# word_norm_post        0.000049
# word_norm_pre         0.000047
# diff                  0.000003
# Name: 6723, dtype: object
# word              sitkeyttä
# word_norm_post     0.000049
# word_norm_pre      0.000047
# diff               0.000003
# Name: 10665, dtype: object
# word              tervetulleena
# word_norm_post         0.000292
# word_norm_pre           0.00029
# diff                   0.000002
# Name: 11897, dtype: object
# word              heikennyksiin
# word_norm_post         0.000082
# word_norm_pre          0.000079
# diff                   0.000002
# Name: 1963, dtype: object
# word              esittelevänä
# word_norm_post        0.000049
# word_norm_pre         0.000047
# diff                  0.000002
# Name: 1444, dtype: object
# word              vaalikampanjassa
# word_norm_post            0.000049
# word_norm_pre             0.000047
# diff                      0.000002
# Name: 13491, dtype: object
# word              varakkaimmat
# word_norm_post        0.000146
# word_norm_pre         0.000144
# diff                  0.000002
# Name: 13994, dtype: object
# word              keskisuomalaisena
# word_norm_post             0.000049
# word_norm_pre              0.000047
# diff                       0.000002
# Name: 3898, dtype: object
# word              apulaisoikeusasiamiehet
# word_norm_post                   0.000032
# word_norm_pre                     0.00003
# diff                             0.000002
# Name: 455, dtype: object
# word              luontopalveluista
# word_norm_post             0.000032
# word_norm_pre               0.00003
# diff                       0.000002
# Name: 5927, dtype: object
# word              käsiteltävänään
# word_norm_post           0.000032
# word_norm_pre             0.00003
# diff                     0.000002
# Name: 5112, dtype: object
# word              seurauksenahan
# word_norm_post          0.000032
# word_norm_pre            0.00003
# diff                    0.000002
# Name: 10503, dtype: object
# word              hallitusoppositio-rajojen
# word_norm_post                     0.000057
# word_norm_pre                      0.000055
# diff                               0.000002
# Name: 1832, dtype: object
# word              alkutuotannon
# word_norm_post         0.000089
# word_norm_pre          0.000088
# diff                   0.000001
# Name: 286, dtype: object
# word              riihimäellä
# word_norm_post       0.000032
# word_norm_pre        0.000032
# diff                 0.000001
# Name: 9866, dtype: object
# word              tuotantoeläimiä
# word_norm_post           0.000099
# word_norm_pre            0.000098
# diff                     0.000001
# Name: 12699, dtype: object
# word               menesty
# word_norm_post    0.000064
# word_norm_pre     0.000064
# diff                   0.0
# Name: 6454, dtype: object
# word              mahdollistamassa
# word_norm_post            0.000049
# word_norm_pre             0.000049
# diff                           0.0
# Name: 6257, dtype: object
# word               kuinkas
# word_norm_post    0.000082
# word_norm_pre     0.000082
# diff                   0.0
# Name: 4705, dtype: object
# word              houkuttelevana
# word_norm_post          0.000032
# word_norm_pre           0.000032
# diff                         0.0
# Name: 2223, dtype: object
# word              parantuisi
# word_norm_post      0.000146
# word_norm_pre       0.000146
# diff                     0.0
# Name: 8365, dtype: object
# word              velkaannuttu
# word_norm_post        0.000032
# word_norm_pre         0.000032
# diff                       0.0
# Name: 14205, dtype: object
# word              täyttäville
# word_norm_post       0.000032
# word_norm_pre        0.000032
# diff                      0.0
# Name: 13214, dtype: object
# word              yhdistävät
# word_norm_post      0.000032
# word_norm_pre       0.000032
# diff                     0.0
# Name: 14856, dtype: object
# word              liikunnallista
# word_norm_post          0.000032
# word_norm_pre           0.000032
# diff                         0.0
# Name: 5664, dtype: object

# %%
# next: "{directory}/csv_analysis/speeches_combined_plus_length.csv"
# check in which contexts (content) these words have been used -> extract content if words exists there -> check what kinds of sentences these match (content)
df_all_speeches = pd.read_csv(f'{directory}/csv_analysis/speeches_combined_plus_length.csv', sep=';', header=0, dtype='str')
df_all_speeches['year'] = pd.to_numeric(df_all_speeches['year'], downcast='integer')
df_all_speeches['n_words_in_speech'] = pd.to_numeric(df_all_speeches['n_words_in_speech'], downcast='integer')

# clean content (speech), create it into a string of cleaned words, store in new column content_cleaned
df_all_speeches.loc[:, 'content_cleaned'] = df_all_speeches['content'].apply(lambda x: ' '.join([clean_string(i) for i in x.split()]) if isinstance(x, str) else None)

# create a pattern to match the desired words from compare_word_norm_sums dataframe, column word
pattern = '|'.join(compare_word_norm_sums['word'].astype(str))

# filter rows from df_all_speeches where a word in content_cleaned matches a word in the regex pattern
df_filtered = df_all_speeches[df_all_speeches['content_cleaned'].str.contains(pattern, case=False, na=False)]

# now filtered. next: which words of compare_word_norm_sums['word'] appear in the speech, store in new column
words_set = set(compare_word_norm_sums['word'].dropna().unique()) # words_set contains the mutual words
df_filtered = df_filtered.copy()
# store matched words in a new column: filter_words
df_filtered.loc[:, 'filter_words'] = df_filtered['content_cleaned'].apply(lambda x: ','.join([i for i in x.split() if i in words_set]) if isinstance(x, str) else None)

# keep rows of df_filtered where len('filter_words') > 0 -> this means that something was matched
df_filtered = df_filtered[df_filtered['filter_words'].str.len()>0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 7
#       5 df_all_speeches['n_words_in_speech'] = pd.to_numeric(df_all_speeches['n_words_in_speech'], downcast='integer')
#       6 pattern = '|'.join(compare_word_norm_sums['word'].astype(str))
# ----> 7 df_filtered = df_all_speeches[df_all_speeches['content'].str.contains(pattern, case=False, na=False)]
#       9 # now filtered. next: which words of compare_word_norm_sums['word'] appear in the speech, store in new column
#      10 words_set = set(compare_word_norm_sums['word'].dropna().unique()) # words_set contains the mutual words
#
# File c:\Users\OMISTAJA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\accessor.py:140, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     135     msg = (
#     136         f"Cannot use .str.{func_name} with values of "
#     137         f"inferred dtype '{self._inferred_dtype}'."
#     138     )
#     139     raise TypeError(msg)
# --> 140 return func(self, *args, **kwargs)
#
# File c:\Users\OMISTAJA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\accessor.py:1346, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1338 if regex and re.compile(pat).groups:
#    1339     warnings.warn(
#    1340         "This pattern is interpreted as a regular expression, and has "
#    1341         "match groups. To actually get the groups, use str.extract.",
#    1342         UserWarning,
#    1343         stacklevel=find_stack_level(),
#    1344     )
# -> 1346 result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1347 return self._wrap_result(result, fill_value=na, returns_string=False)
#
# File c:\Users\OMISTAJA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\object_array.py:162, in ObjectStringArrayMixin._str_contains(self, pat, case, flags, na, regex)
#     154 if na is not lib.no_default and not isna(na) and not isinstance(na, bool):
#     155     # GH#59561
#     156     warnings.warn(
#     157         "Allowing a non-bool 'na' in obj.str.contains is deprecated "
#     158         "and will raise in a future version.",
#     159         FutureWarning,
#     160         stacklevel=find_stack_level(),
#     161     )
# --> 162 return self._str_map(f, na, dtype=np.dtype("bool"))
#
# File c:\Users\OMISTAJA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\object_array.py:82, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      80 map_convert = convert and not np.all(mask)
#      81 try:
# ---> 82     result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      83 except (TypeError, AttributeError) as err:
#      84     # Reraise the exception if callable `f` got wrong number of args.
#      85     # The user may want to be warned by this, instead of getting NaN
#      86     p_err = (
#      87         r"((takes)|(missing)) (?(2)from \d+ to )?\d+ "
#      88         r"(?(3)required )positional arguments?"
#      89     )
#
# File pandas/_libs/lib.pyx:2922, in pandas._libs.lib.map_infer_mask()
#
# File pandas/_libs/lib.pyx:2959, in pandas._libs.lib._map_infer_mask()
#
# File c:\Users\OMISTAJA\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\strings\object_array.py:147, in ObjectStringArrayMixin._str_contains.<locals>.<lambda>(x)
#     143         flags |= re.IGNORECASE
#     145     pat = re.compile(pat, flags=flags)
# --> 147     f = lambda x: pat.search(x) is not None
#     148 else:
#     149     if case:
#
# KeyboardInterrupt:

# %%
# demonstrate what df_filtered contains
df_filtered.head(1).T
# Out:
#                                                                         7
# speech_id                                                        2015_1_8
# session                                                            1/2015
# date                                                           2015-04-28
# start_time                                                          12.01
# end_time                                                            13.31
# given                                                              Pertti
# family                                                         Salolainen
# role                                                          Ikäpuhemies
# party                                                                 KOK
# topic                   Toisen varapuhemiehen vaali>>>Vaali  VAA 3/201...
# content                 Nyt seuraa toisen varapuhemiehen vaali. Vaali ...
# speech_type                                           PuhemiesPuheenvuoro
# mp_uri                                  http://ldf.fi/semparl/people/p259
# gender                                                               Male
# birth                                                          1940-01-01
# party_uri                            http://ldf.fi/semparl/groups/Q304191
# parliamentary_role                                         Hallituspuolue
# group_uri               http://ldf.fi/semparl/groups/g2576146140370716301
# status                                                             Valmis
# version                                                               5.3
# link                    https://www.eduskunta.fi/FI/vaski/PoytakirjaAs...
# lang                                                                fi:sv
# name_in_source                              Ikäpuhemies Pertti Salolainen
# speaker_id                                                            NaN
# speech_start                                                          NaN
# speech_end                                                            NaN
# speech_status                                                         NaN
# speech_version                                                        NaN
# url                        http://ldf.fi/semparl/speeches/s2015_1_001_008
# content_lemmatized                                                    NaN
# content_lemmatized_pos                                                NaN
# year                                                                 2015
# n_words_in_speech                                                     NaN
# content_cleaned         nyt seuraa toisen varapuhemiehen vaali vaali t...
# filter_words                                      wallinheimo,wallinheimo
